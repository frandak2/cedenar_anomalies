# %% [markdown]
# # Exploración datos Zentry

# %%
import os

import pandas as pd

from cedenar_anomalies.utils.paths import (
    data_interim_dir,
    data_processed_dir,
    data_raw_dir,
)

# %%
os.getcwd()
# Out:
# '/Users/frandak2/Documents/repos/cedenar_anomalies/notebooks'

# %%
pd.set_option("display.max_rows", None)  # Mostrar todas las filas
pd.set_option("display.max_columns", None)  # Mostrar todas las columnas

# %% [markdown]
# ### Datos 2023

# %%
# ruta_archivo = 'J:\\JESSICA\\Jessica\\Rafael\\igrid\\cedenar\\python_zentr\\zentry\\plain3.csv'  # Reemplaza con tu ruta
ruta_archivo = data_raw_dir("plain3.csv")
df_2023 = pd.read_csv(ruta_archivo)
# Out:
# /var/folders/pq/cm_j30pd6d5gvwryc4gttm2h0000gn/T/ipykernel_3963/4246414070.py:3: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_2023 = pd.read_csv(ruta_archivo)

# %%
df_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16505432 entries, 0 to 16505431
# Data columns (total 5 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   odt       int64
#  1   id        int64
#  2   item      object
#  3   tipodato  object
#  4   value     object
# dtypes: int64(2), object(3)
# memory usage: 629.6+ MB

# %%
df_2023.sample(5)
# Out:
#               odt    id                                     item tipodato  \
# 8485482   2543858   281                     Lugar De Expedición   varchar
# 6434508    964369  1389                         Proteccion Datos  varchar
# 14469464  1504835  1442  Total Carga Directa Fuera de Medida (W)  numeric
# 2137447   1812992   214                               Sello Caja  integer
# 10126840  1496097    32                       Color Home Display  varchar
#
#                                                       value
# 8485482                                              TUMACO
# 6434508   CON SU FIRMA, USTED AUTORIZA A CEDENAR S.A. E....
# 14469464                                                0.0
# 2137447                                              716757
# 10126840                                               GRIS

# %%
df_zonas = df_2023[df_2023.id == 1].reset_index(drop=True)
df_odt_number = df_2023[df_2023.id == 288].reset_index(drop=True)

# %%
df_odt_number.head(2)
# Out:
#        odt   id            item tipodato   value
# 0  2584979  288  Código Interno  integer  538741
# 1  2584978  288  Código Interno  integer  302756

# %%
df_zonas.head(2)
# Out:
#        odt  id  item tipodato      value
# 0  2183030   1  Zona  varchar     CENTRO
# 1  1552391   1  Zona  varchar  OCCIDENTE

# %% [markdown]
# ## Particiones datasets

# %% [markdown]
# ### 2023

# %%
# evento2023 = df_2023.copy()
# # variable 'id' es de tipo categórico
# evento2023['id'] = evento2023['id'].astype('category')
#
# # Obtener los niveles únicos de la variable 'id'
# niveles_id = evento2023['id'].cat.categories
#
# # Crear un dataset por cada nivel de 'id'
# for nivel in niveles_id:
#     # Filtrar el dataset por cada nivel
#     subset_nivel = evento2023[evento2023['id'] == nivel]
#
#     # Guardar el datasets
#     globals()[f"evento2023_{nivel}"] = subset_nivel
#
#     subset_nivel.to_csv(data_interim_dir(f"evento2023_{nivel}.csv"), index=False)
#
# print("Proceso completado.")

# %% [markdown]
# ### Leer las particiones sin leer el archivo mayor

# %% [markdown]
# ### 2023

# %%
# Directorio donde están las particiones
# directorio = 'J:\\JESSICA\\Jessica\\Rafael\\igrid\\cedenar\\python_zentr'

# Cargar los niveles únicos desde el CSV
# niveles_id = pd.read_excel(os.path.join(directorio, 'identificadores_unicos2023.xlsx'))['id_2023']
niveles_id = [
    1,
    1442,
    288,
    8,
    237,
    23,
    24,
    33,
    598,
    601,
    43,
    99,
    35,
    111,
    599,
    108,
    603,
    190,
    192,
    588,
    248,
    591,
    602,
    41,
    211,
    74,
    1889,
    597,
    600,
    37,
    1407,
    1410,
    68,
    1328,
    1334,
    594,
    67,
    1408,
    1352,
    1405,
    1283,
    1343,
    1346,
    1292,
    1298,
    69,
    1331,
    202,
    1349,
]

# Leer las particiones y guardarlas en variables dinámicas
for nivel in niveles_id:
    nombre_archivo = f"evento2023_{nivel}.csv"
    ruta_archivo = data_interim_dir(nombre_archivo)

    if os.path.exists(ruta_archivo):
        globals()[f"evento2023_{nivel}"] = pd.read_csv(ruta_archivo)
        # print(f"Cargado: {nombre_archivo}")
    else:
        print(f"No encontrado: {nombre_archivo}")

print("Todas las particiones han sido cargadas.")
# Out:
# Todas las particiones han sido cargadas.

# %%
df_odt_number.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 102905 entries, 0 to 102904
# Data columns (total 5 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   odt       102905 non-null  int64
#  1   id        102905 non-null  int64
#  2   item      102905 non-null  object
#  3   tipodato  102905 non-null  object
#  4   value     102905 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 3.9+ MB

# %%
df_odt_number.head(2)
# Out:
#        odt   id            item tipodato   value
# 0  2584979  288  Código Interno  integer  538741
# 1  2584978  288  Código Interno  integer  302756

# %%
evento2023_288.head(2)
# Out:
#        odt   id            item tipodato   value
# 0  2584979  288  Código Interno  integer  538741
# 1  2584978  288  Código Interno  integer  302756

# %% [markdown]
# ### Filtrar datos solo Zona PACIFICO

# %% [markdown]
# ### 2023

# %%
# ruta_archivo = 'J:\\JESSICA\\Jessica\\Rafael\\igrid\\cedenar\\python_zentr\\evento2023_1.csv'  # Reemplaza con tu ruta
ruta_archivo = data_interim_dir("evento2023_1.csv")
evento2023_1 = pd.read_csv(ruta_archivo)
evento2023_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144070 entries, 0 to 144069
# Data columns (total 5 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   odt       144070 non-null  int64
#  1   id        144070 non-null  int64
#  2   item      144070 non-null  object
#  3   tipodato  144070 non-null  object
#  4   value     144070 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 5.5+ MB

# %%
df_zonas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144070 entries, 0 to 144069
# Data columns (total 5 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   odt       144070 non-null  int64
#  1   id        144070 non-null  int64
#  2   item      144070 non-null  object
#  3   tipodato  144070 non-null  object
#  4   value     144070 non-null  object
# dtypes: int64(2), object(3)
# memory usage: 5.5+ MB

# %%
evento2023_1["value"].value_counts()
# Out:
# value
# SUR          31438
# CENTRO       28640
# NORTE        28085
# OCCIDENTE    26386
# PACIFICO     23847
# CE            3923
# CN             693
# NO             509
# SU             507
# OC              42
# Name: count, dtype: int64

# %%
# Filtrar los casos donde 'value' es "PACIFICO"
odt_pacifico = evento2023_1[evento2023_1["value"] == "PACIFICO"]["odt"]

# Exportar el resultado a un CSV
odt_pacifico.to_csv(data_interim_dir("odt_pacifico_2023.csv"), index=False)

print("Exportación completada: 'odt_pacifico_2023.csv'")
# Out:
# Exportación completada: 'odt_pacifico_2023.csv'

# %%
odt_pacifico_2023 = pd.read_csv(data_interim_dir("odt_pacifico_2023.csv"))

# %%
# First, make sure we're selecting both columns needed
df_zona_pacifico = df_zonas[df_zonas["value"] == "PACIFICO"][["odt", "value"]]

# Create an explicit copy
df_zona_pacifico = df_zona_pacifico.copy()

# %%
odt_pacifico_2023.head(2)
# Out:
#        odt
# 0  1561972
# 1  1813259

# %% [markdown]
# ## Extraer 288 de cada dataset y unir a odt de pacifico

# %%
ruta_archivo = data_interim_dir("evento2023_288.csv")
evento2023_288 = pd.read_csv(ruta_archivo)
evento2023_288.head(2)
# Out:
#        odt   id            item tipodato   value
# 0  2584979  288  Código Interno  integer  538741
# 1  2584978  288  Código Interno  integer  302756

# %%
df_odt_number.head(2)
# Out:
#        odt   id            item tipodato   value
# 0  2584979  288  Código Interno  integer  538741
# 1  2584978  288  Código Interno  integer  302756

# %%
def procesar_niveles(anio, niveles, nuevo_dataset):
    """
    Función para agregar datos de múltiples datasets a un dataset base usando la columna 'odt'.

    Parámetros:
    - anio (int): Año de los datasets.
    - niveles (list): Lista de IDs de variables a procesar.
    - nuevo_dataset (DataFrame): Dataset base al que se le agregarán las columnas.

    Retorna:
    - DataFrame con las columnas agregadas.
    """
    nuevo_dataset = nuevo_dataset.copy()

    for nivel in niveles:
        df_actual = globals().get(f"evento{anio}_{nivel}")

        if df_actual is not None:
            if "odt" in df_actual.columns and "value" in df_actual.columns:
                df_actual = df_actual[["odt", "value"]].drop_duplicates(subset="odt")
                nuevo_dataset[f"item_{nivel}"] = nuevo_dataset["odt"].map(
                    df_actual.set_index("odt")["value"]
                )

                # Convertir a enteros si no hay valores nulos
                if not nuevo_dataset[f"item_{nivel}"].isna().all():
                    nuevo_dataset[f"item_{nivel}"] = (
                        nuevo_dataset[f"item_{nivel}"].fillna(0).astype(int)
                    )

                print(f"✔️ Procesado: evento{anio}_{nivel}")
            else:
                print(f"⚠️ Columnas faltantes en: evento{anio}_{nivel}")
        else:
            print(f"⚠️ No encontrado: evento{anio}_{nivel}")

    # Guardar el dataset consolidado
    output_path = data_interim_dir(f"nuevo_dataset_{anio}.csv")
    nuevo_dataset.to_csv(output_path, index=False)
    print(f"✅ Proceso completado. Dataset guardado en {output_path}.")

    return nuevo_dataset

# %%
# Lista de ids de variables
niveles = [288]

# Base principal (odt_pacifico) ya cargada
nuevo_dataset = odt_pacifico_2023.copy()

nuevo_dataset_2023 = procesar_niveles(2023, niveles, nuevo_dataset)
nuevo_dataset_2023.head(2)
# Out:
# ✔️ Procesado: evento2023_288
# ✅ Proceso completado. Dataset guardado en /Users/frandak2/Documents/repos/cedenar_anomalies/data/interim/nuevo_dataset_2023.csv.
#        odt  item_288
# 0  1561972   1234558
# 1  1813259   1042646

# %%
df_odt_number = df_odt_number.drop_duplicates(subset="odt")
df_odt_number.head(2)
# Out:
#        odt   id            item tipodato   value
# 0  2584979  288  Código Interno  integer  538741
# 1  2584978  288  Código Interno  integer  302756

# %%
df_zona_pacifico.head(2)
# Out:
#         odt     value
# 7   1561972  PACIFICO
# 11  1813259  PACIFICO

# %%
# df_odt_number.set_index('odt')['value']
df_zona_pacifico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 23847 entries, 7 to 144061
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   odt     23847 non-null  int64
#  1   value   23847 non-null  object
# dtypes: int64(1), object(1)
# memory usage: 558.9+ KB

# %%
df_zona_pacifico["odt"]
# Out:
# 7         1561972
# 11        1813259
# 15        1458468
# 17        1458468
# 18        1462340
# 20        1539936
# 24        1542527
# 26        1458468
# 27        1539936
# 30        1491662
# 31        1539936
# 32        1491662
# 33        1517683
# 38        1542526
# 40        1491662
# 41        1517683
# 56        1539935
# 60        1538312
# 61        1542536
# 62        1539935
# 63        1539311
# 78        1536482
# 80        1091220
# 86        1539893
# 88        1539892
# 89        1539890
# 91        1539891
# 95        1539304
# 96        1539305
# 97        1539306
# 98        1888892
# 99        1538044
# 100       1538079
# 102       1538043
# 117       2178546
# 121       1545536
# 124       2185377
# 128       2180128
# 132       2185381
# 136       2180116
# 139       2180117
# 141       1545524
# 142       1545457
# 167       1542529
# 173       1542531
# 184       1545451
# 185       1542530
# 188       2119143
# 191       2119143
# 195       2119143
# 196       1545452
# 197       1537060
# 200       2119143
# 201       1537060
# 205       2184694
# 207       1539563
# 209       2101341
# 213       2101340
# 214       1537060
# 216       1539563
# 228       1544169
# 239       1539563
# 245       1544169
# 249       1539560
# 250       1489329
# 266       1544169
# 276       1539560
# 284       1539561
# 290       1539560
# 302       1539561
# 306       1539564
# 311       1539561
# 321       1539564
# 324       1470079
# 327       1539564
# 334       1539566
# 336       1539566
# 342       1539566
# 345       1537066
# 357       1455389
# 358       1539568
# 365       1537063
# 369       1526750
# 380       1543699
# 383       1542594
# 386       1542591
# 390       1231069
# 391       1542592
# 394       1539898
# 395       1517704
# 402       1539896
# 410       2184878
# 411       1539897
# 413       2184875
# 419       2184886
# 424       2184881
# 436       2182661
# 438       1543696
# 439       1539894
# 441       1538085
# 443       2184961
# 459       1399674
# 460       1491723
# 461       2183184
# 462       1399674
# 464       1491667
# 465       2183184
# 468       2183184
# 469       1399674
# 474       2183185
# 478       1539352
# 480       1539352
# 482       2183184
# 484       2183185
# 492       2183185
# 498       2183183
# 502       2183185
# 503       2183183
# 509       2183183
# 514       1539303
# 515       1539303
# 516       2180391
# 518       1539302
# 519       1539302
# 520       2183124
# 521       1539301
# 522       1539300
# 523       1539301
# 526       1538082
# 528       1538084
# 531       1538080
# 532       1455393
# 533       1508021
# 535       1508021
# 537       1508022
# 539       1508022
# 540       1538364
# 541       1538364
# 543       1538363
# 545       1538363
# 546       1229084
# 548       1236064
# 550       1229076
# 552       1229076
# 553       1534390
# 555       1534390
# 569       2186738
# 574       2183119
# 579       1537048
# 582       1537047
# 583       1537049
# 585        813319
# 586        892055
# 587       1537875
# 588       1466607
# 589       2180229
# 593       2180225
# 594        813319
# 602        813319
# 643       1537052
# 646       1537055
# 647       1537051
# 648       1537056
# 649       1537053
# 651       1527584
# 703       1656795
# 710       1537560
# 712       1537545
# 718       1537875
# 725        864511
# 726        864511
# 729        864511
# 730        864511
# 732        864511
# 747       1813259
# 750        892055
# 752        977122
# 753        924097
# 766       1438389
# 768        999292
# 770       1001079
# 774       1017303
# 784       1278642
# 786       1278642
# 792       1278642
# 793       1278642
# 805       1430757
# 807       1195545
# 808       1450473
# 810       1341153
# 812       1341153
# 814       1341153
# 825       1341153
# 835       1517681
# 844       1466607
# 851       1539309
# 861       1539998
# 864       1539994
# 867       1539996
# 869       1496122
# 876       1496122
# 885       1517682
# 888       1535294
# 889       1538313
# 893       1538314
# 917       1543697
# 918       1543697
# 919       1543698
# 925       1538043
# 927       1538039
# 941       1538093
# 942       1538091
# 944       1538092
# 947       1538094
# 979       2183118
# 990       1208712
# 991       1464680
# 996       1537054
# 1021      1491666
# 1026      1545431
# 1040      2183118
# 1050      1545424
# 1054      1462332
# 1059      1545528
# 1069      1470083
# 1075      1545525
# 1077      1545534
# 1080      1545428
# 1081      1470004
# 1084      1545447
# 1086      1488977
# 1098      1466048
# 1099      1545444
# 1106      1357807
# 1108      1547155
# 1109      1545248
# 1119      2180518
# 1123      1547210
# 1124      1462340
# 1129      1430563
# 1130      1430562
# 1152      1545530
# 1153      1430565
# 1158      1357807
# 1160      1545449
# 1161      1547262
# 1183      1430564
# 1186      1545426
# 1188      1541905
# 1207      1547265
# 1229      1357807
# 1232      1545456
# 1233      1545538
# 1258      1539993
# 1259      1539995
# 1260      1545523
# 1264      1545379
# 1267      1545526
# 1270      1267587
# 1288      1545256
# 1294      1539997
# 1295      1246570
# 1310      1545453
# 1314      1545454
# 1320      1545455
# 1324      1545450
# 1328      1888892
# 1333      1462341
# 1335      2070684
# 1336      1462334
# 1342      2080326
# 1365      1547223
# 1368      1545253
# 1371      1409097
# 1374      1545542
# 1377      1815086
# 1380      1539308
# 1385      1813259
# 1388      1539895
# 1395      1539307
# 1396      1545249
# 1410      1539901
# 1411      1375559
# 1413      1541102
# 1417      1462340
# 1421      1539900
# 1432      1545445
# 1454      1539899
# 1455      1249394
# 1465      1888892
# 1468      1545251
# 1475      1455167
# 1492      1545250
# 1496      2070684
# 1501      1462334
# 1502      1547264
# 1509      1547263
# 1522      2080326
# 1531      1545246
# 1534      1815086
# 1535      1542593
# 1547      1517703
# 1549      1542528
# 1564      1462341
# 1565      1545246
# 1568      1545245
# 1579      1852513
# 1580      1515868
# 1581      1515868
# 1582      2049584
# 1583      2049584
# 1584      1954349
# 1585      1954349
# 1587      2206020
# 1588      2206020
# 1622      1971331
# 1623      1971329
# 1624      2219896
# 1625      2657368
# 1636      1550265
# 1641      2320292
# 1642      2320292
# 1643      2320292
# 1644      2320292
# 1645      2320292
# 1660      1971328
# 1661      1971328
# 1662      1716116
# 1663      2609356
# 1664      1825094
# 1665      1825094
# 1666      2182681
# 1669      1449229
# 1670      2609356
# 1673      1755871
# 1675      2255509
# 1676      2240719
# 1677      2258713
# 1678      2001688
# 1679      1755869
# 1690      2040722
# 1691      2040722
# 1692      2040722
# 1693      2040722
# 1694      2040722
# 1695      2072255
# 1696      2072255
# 1697      2072255
# 1698      2072255
# 1699      2072255
# 1700      2072255
# 1701      2072255
# 1702      2072255
# 1703      2072255
# 1704      2072255
# 1719      2236168
# 1720      2236168
# 1721      1561918
# 1722      1561918
# 1723      1561918
# 1724      1557678
# 1725      1557678
# 1726      2662903
# 1734      2441915
# 1735      2441915
# 1736      2441915
# 1746      2687536
# 1747      2687536
# 1760      2480835
# 1766      2691619
# 1767      2691619
# 1768      2688060
# 1769      2688060
# 1770      2688059
# 1771      2688059
# 1782      2585005
# 1911      2687974
# 1912      2583129
# 1921      2687891
# 1924      2687890
# 1925      2687895
# 1931      2663543
# 1932      2663543
# 1933      2684997
# 1946      2691462
# 1947      2691457
# 1948      2691461
# 1968      2480835
# 2008      2544020
# 2009      2687885
# 2010      2525398
# 2011      2663275
# 2015      2687536
# 2016      2687536
# 2017      2602158
# 2018      2602158
# 2019      2691595
# 2020      2691595
# 2021      2643932
# 2022      2643932
# 2039      2633061
# 2040      2633061
# 2062      2687532
# 2073      2633061
# 2074      2633061
# 2075      2633061
# 2076      2633061
# 2077      2633061
# 2078      2633061
# 2079      2633061
# 2080      2633061
# 2081      2633061
# 2097      2548853
# 2124      2691582
# 2125      2687971
# 2126      2687973
# 2127      2684644
# 2128      2688132
# 2129      2688130
# 2130      2688131
# 2154      2691617
# 2155      2691619
# 2156      2691621
# 2157      2691623
# 2158      2691622
# 2260      2687922
# 2261      2691593
# 2262      2691595
# 2263      2691594
# 2264      2687919
# 2265      2687917
# 2267      2687918
# 2279      2691749
# 2323      2663543
# 2340      2605082
# 2341      2688800
# 2360      2546328
# 2363      2665450
# 2437      2691461
# 2484      2691462
# 2533      2663543
# 2534      2684997
# 2555      2688800
# 2556      2691700
# 2596      2691457
# 2597      2691457
# 2598      2691457
# 2605      2687157
# 2617      2687157
# 2643      2687177
# 2663      2657374
# 2712      2688245
# 2713      2685430
# 2714      2685429
# 2715      2685428
# 2727      2685427
# 2728      2685547
# 2729      2685548
# 2730      2688082
# 2731      2688081
# 2732      2688080
# 2734      2688078
# 2735      2688077
# 2736      2688076
# 2737      2688079
# 2738      2688121
# 2739      2688122
# 2740      2688123
# 2741      2688124
# 2742      2688133
# 2753      2684172
# 2754      2684659
# 2755      2687528
# 2756      2687533
# 2758      2687532
# 2765      2448799
# 2766      2687536
# 2767      2687536
# 2768      2687534
# 2769      2687534
# 2770      2320293
# 2771      2684993
# 2772      2687528
# 2773      2687528
# 2774      2684994
# 2775      2687886
# 2776      2687894
# 2777      2687898
# 2778      2688060
# 2779      2688059
# 2780      2687897
# 2782      2684996
# 2783      2689112
# 2784      2663546
# 2785      2663544
# 2786      2689113
# 2793      2687532
# 2794      2687533
# 2811      2687535
# 2812      2684312
# 2813      2684172
# 2814      2684659
# 2837      2682020
# 2838      2682021
# 2839      2682022
# 2840      2682023
# 2841      2687910
# 2842      2687908
# 2851      2687909
# 2874      2663093
# 2875      2663092
# 2876      2663087
# 2877      2689112
# 2913      2689113
# 2914      2633822
# 2915      2633822
# 2916      2240736
# 2917      2240736
# 2920      2684657
# 2921      2663091
# 2923      2684656
# 2926      2684655
# 2927      2688393
# 2934      2684658
# 2935      2684650
# 2951      2612514
# 2952      2684654
# 2954      2684653
# 2955      2663546
# 2956      2663544
# 2960      2687908
# 2961      2655404
# 2979      2663276
# 2981      2687908
# 2982      2687908
# 2983      2687908
# 2984      2687908
# 2985      2655202
# 2986      2602158
# 2987      2172310
# 2999      2687909
# 3000      2687909
# 3003      2687909
# 3004      2687909
# 3005      2687909
# 3009      2687884
# 3027      2687910
# 3029      2401714
# 3044      2684645
# 3045      2684637
# 3046      2684645
# 3047      2684639
# 3048      2684637
# 3049      2622394
# 3050      2684639
# 3051      2658110
# 3052      2622394
# 3053      2622396
# 3054      2658110
# 3055      2684642
# 3061      2647356
# 3062      2684630
# 3063      2685425
# 3064      2295474
# 3098      2684838
# 3099      2663088
# 3100      2663089
# 3101      2663090
# 3123      2448799
# 3124      2684993
# 3125      2684994
# 3126      2684996
# 3131      2686935
# 3148      2682022
# 3149      2682023
# 3150      2682020
# 3155      2663284
# 3163      2663278
# 3201      2601147
# 3222      2682021
# 3223      2682021
# 3254      2548852
# 3255      2548852
# 3272      2547640
# 3273      2655003
# 3274      2666066
# 3275      2540668
# 3278      2654998
# 3300      2663283
# 3351      2684631
# 3352      2684627
# 3360      2684840
# 3402      2684835
# 3403      2684836
# 3426      2663280
# 3460      2666070
# 3461      2666068
# 3462      2666067
# 3463      2655002
# 3464      2666069
# 3465      2666064
# 3485      2633819
# 3488      2633831
# 3492      2633822
# 3493      2609178
# 3494      2609179
# 3520      2609356
# 3521      2609356
# 3528      2609356
# 3535      2609356
# 3536      2609356
# 3537      2609356
# 3545      2647461
# 3568      2665952
# 3569      2647352
# 3570      2647357
# 3571      2665955
# 3572      2665956
# 3573      2665953
# 3574      2665954
# 3756      2663539
# 3757      2663538
# 3758      2663537
# 3759      2663530
# 3765      2663536
# 3770      2663534
# 3775      2663533
# 3780      2663532
# 3782      2663531
# 3817      2681591
# 3935      2633826
# 3936      2633826
# 3937      2633827
# 3938      2633827
# 3939      2658352
# 3940      2658352
# 3941      2636011
# 3942      2636011
# 3943      2583443
# 3944      2583443
# 3945      2643937
# 3946      2643937
# 3947      2621626
# 3948      2621626
# 3949      2559224
# 3950      2559224
# 4216      2668552
# 4217      2668552
# 4297      2644504
# 4298      2644503
# 4299      2644505
# 4300      2644501
# 4301      2601948
# 4302      2053760
# 4360      2647460
# 4434      2663274
# 4435      2662904
# 4490      2662906
# 4491      2662906
# 4495      2666014
# 4498      2662905
# 4499      2665467
# 4523      2633830
# 4524      2633835
# 4525      2633835
# 4526      2633836
# 4527      2633834
# 4528      2633833
# 4645      2663279
# 4646      2663282
# 4647      2663282
# 4648      2663279
# 4649      2663279
# 4650      2663273
# 4651      2663277
# 4654      2663282
# 4655      2663279
# 4656      2663279
# 4657      2663277
# 4658      2663282
# 4659      2663277
# 4660      2663277
# 4661      2663277
# 4662      2663277
# 4663      2663277
# 4664      2663273
# 4665      2663273
# 4666      2663273
# 4667      2663285
# 4668      2663285
# 4669      2663273
# 4670      2663285
# 4671      2663285
# 4672      2663285
# 4695      2657370
# 4718      2654999
# 4812      2665983
# 4887      2665982
# 4894      2665981
# 4900      2665981
# 4927      2665464
# 4930      2473003
# 4931      2656718
# 4932      2656719
# 4933      2656720
# 4935      2656717
# 4937      2549657
# 4938      2654658
# 4939      2658350
# 4980      2656720
# 4981      2656719
# 4982      2656718
# 4983      2656717
# 4984      2633833
# 4985      2633832
# 4986      2609357
# 4987      2663300
# 4995      2654806
# 5002      2655202
# 5003      2654993
# 5004      2654995
# 5005      2654994
# 5006      2654992
# 5008      2655000
# 5018      2592630
# 5021      2665449
# 5022      2592630
# 5040      2644502
# 5041      2612521
# 5042      2612522
# 5043      2612524
# 5044      2240736
# 5110      2654806
# 5199      2663545
# 5200      2663547
# 5202      2665448
# 5203      2663548
# 5204      2618610
# 5211      2618610
# 5215      2634960
# 5216      2636014
# 5217      2665438
# 5218      2394471
# 5219      2643902
# 5226      2654826
# 5228      2636014
# 5241      2654819
# 5245      2654656
# 5246      2658366
# 5248      2634960
# 5261      2658367
# 5262      2663548
# 5263      2663547
# 5264      2663545
# 5281      2621603
# 5282      2658366
# 5283      1545437
# 5285      2600566
# 5289      2180128
# 5290      2394471
# 5298      2665438
# 5300      1234195
# 5301      1234195
# 5302      2658364
# 5327      2635069
# 5329      2605078
# 5335      2635069
# 5345      2665437
# 5373      2636012
# 5374      2654517
# 5426      2658349
# 5427      2658352
# 5428      2658355
# 5439      2658371
# 5454      2182592
# 5465      2609586
# 5467      2401789
# 5471      2609586
# 5473      2662903
# 5476      2662903
# 5477      2662903
# 5479      2662903
# 5484      2240225
# 5487      2658370
# 5491      2219895
# 5494      2658368
# 5496      2403096
# 5505      2658354
# 5514      2223308
# 5524      2178734
# 5528      2247084
# 5531      2658353
# 5532      2477379
# 5536      2643901
# 5546      2401787
# 5548      2535301
# 5555      2658351
# 5563      2636013
# 5565      2633838
# 5566      2633839
# 5567      2633818
# 5568      2633823
# 5569      2549468
# 5570      2633826
# 5571      2633827
# 5572      2601137
# 5573      2605042
# 5607      2647354
# 5608      2647353
# 5609      2654985
# 5614      2654988
# 5615      2654986
# 5616      2654987
# 5618      2609585
# 5624      2635717
# 5625      2654373
# 5652      2644101
# 5653      2644102
# 5654      2636011
# 5655      2636010
# 5656      2635717
# 5657      2654373
# 5675      2544042
# 5677      2544042
# 5678      2544042
# 5679      2544042
# 5680      2544036
# 5681      2544042
# 5682      2544036
# 5683      2544036
# 5684      2544042
# 5685      2544042
# 5686      2544036
# 5687      2544036
# 5688      2544036
# 5689      2544018
# 5690      2544018
# 5691      2544018
# 5692      2544018
# 5693      2544018
# 5694      2544018
# 5695      2609585
# 5696      2544018
# 5697      2544018
# 5699      2609585
# 5700      2609585
# 5701      2609585
# 5702      2609585
# 5703      2643927
# 5713      2657369
# 5734      2656329
# 5736      2549684
# 5746      2239658
# 5748      2612520
# 5749      2657377
# 5754      2546525
# 5767      2271621
# 5768      2654824
# 5772      2643929
# 5781      2535417
# 5783      2643903
# 5796      2654823
# 5797      2658321
# 5798      2619251
# 5799      2236135
# 5800      2612518
# 5802      2657368
# 5803      2241234
# 5807      2658298
# 5809      2658273
# 5816      2236140
# 5817      2236140
# 5818      2654820
# 5819      2605072
# 5820      2643925
# 5837      2654827
# 5839      2655001
# 5840      2643907
# 5841      2612517
# 5844      2654821
# 5846      2643914
# 5860      2657375
# 5862      2654825
# 5867      2657367
# 5871      2654822
# 5876      2657376
# 5877      2609581
# 5878      2609579
# 5881      2654518
# 5882      2612519
# 5883      2656328
# 5884      2609581
# 5885      2654518
# 5886      2609579
# 5892      2643916
# 5893      2656328
# 5906      2634961
# 5937      2634961
# 5938      2655412
# 5946      2622036
# 5947      2622036
# 5948      2622036
# 6004      2634962
# 6015      2655412
# 6045      2656330
# 6050      2654513
# 6088      2643906
# 6093      2655425
# 6094      2655425
# 6111      2654516
# 6113      2654515
# 6114      2654514
# 6121      2654809
# 6122      2633094
# 6123      2547649
# 6124      2601148
# 6125      2547652
# 6126      2633091
# 6127      2643908
# 6133      2643910
# 6139      2633829
# 6174      2643905
# 6175      2632424
# 6178      2643905
# 6206      2643915
# 6208      2600570
# 6209      2600570
# 6210      2643932
# 6211      2643938
# 6237      2647351
# 6238      2643938
# 6252      2633061
# 6253      2634454
# 6254      2503868
# 6296      2206023
# 6298      2206023
# 6476      2647496
# 6480      2647496
# 6488      2503868
# 6493      2643911
# 6494      2634955
# 6519      2644104
# 6520      2644103
# 6521      2644100
# 6522      2644100
# 6523      2644098
# 6524      2644098
# 6525      2647309
# 6526      2647309
# 6527      2644097
# 6561      2643920
# 6568      2643924
# 6603      2643912
# 6604      2643923
# 6618      2644118
# 6621      2643921
# 6625      2439147
# 6638      2633842
# 6639      2632908
# 6640      2643928
# 6641      2621653
# 6642      2633283
# 6643      2633283
# 6644      2621653
# 6648      2644117
# 6652      2643716
# 6653      2643717
# 6654      2643937
# 6656      2643933
# 6660      2644116
# 6662      2634317
# 6663      2634002
# 6664      2634008
# 6665      2633655
# 6672      2644115
# 6673      2644114
# 6676      2643926
# 6681      2644114
# 6684      2643717
# 6691      2643934
# 6695      2643930
# 6701      2643716
# 6713      2644099
# 6714      2644105
# 6717      2635719
# 6721      2643931
# 6729      2644114
# 6743      2644112
# 6768      2643918
# 6769      2643918
# 6772      2643904
# 6778      2644113
# 6780      2643936
# 6788      2643917
# 6790      2644111
# 6793      2643935
# 6797      2644110
# 6818      2634007
# 6870      2622029
# 6888      2633825
# 6889      2633824
# 6890      2633828
# 6910      2549662
# 6911      2582374
# 6997      2612523
# 7009      2612515
# 7025      2612516
# 7026      2600758
# 7027      2622154
# 7028      2601950
# 7045      2632418
# 7046      2582374
# 7297      2636015
# 7300      2636015
# 7302      2635718
# 7316      2636016
# 7318      2633277
# 7319      2636016
# 7320      2632423
# 7328      2636039
# 7329      2632419
# 7338      2544048
# 7355      2632417
# 7359      2618188
# 7361      2544040
# 7373      2634164
# 7376      2634311
# 7378      2594049
# 7382      2618187
# 7385      2635821
# 7394      2594050
# 7399      2618155
# 7409      2544045
# 7410      2544041
# 7416      2634959
# 7417      2634314
# 7419      2634959
# 7436      2634958
# 7441      2633095
# 7444      2634958
# 7445      2633279
# 7451      2633280
# 7453      2633278
# 7456      2633282
# 7457      2633283
# 7481      2632409
# 7490      2632416
# 7537      2634714
# 7549      2634313
# 7553      2632730
# 7557      2605099
# 7571      2618153
# 7572      2632410
# 7574      2632415
# 7590      2634312
# 7596      2618152
# 7599      2618150
# 7610      2632420
# 7613      2632420
# 7617      2590204
# 7631      2438715
# 7634      2581775
# 7636      2633296
# 7638      2590220
# 7639      2438715
# 7641      2632414
# 7642      2618182
# 7643      2600408
# 7644      2605096
# 7648      2633090
# 7652      2605073
# 7655      2632413
# 7657      2618195
# 7660      2585006
# 7668      2632412
# 7672      2605074
# 7676      2622395
# 7677      2622395
# 7678      2622397
# 7679      2622395
# 7680      2622397
# 7681      2622397
# 7682      2622398
# 7683      2622398
# 7684      2601145
# 7685      2601145
# 7686      2601144
# 7687      2601139
# 7688      2601144
# 7690      2601139
# 7691      2601138
# 7692      2609182
# 7695      2609180
# 7696      2632422
# 7697      2609180
# 7698      2601138
# 7699      2609183
# 7700      2609182
# 7701      2609183
# 7702      2632411
# 7703      2601151
# 7704      2547638
# 7705      2547642
# 7706      2547639
# 7707      2540672
# 7708      2601149
# 7709      2601146
# 7710      2601150
# 7711      2609587
# 7714      2622257
# 7715      2600937
# 7716      2612725
# 7726      2525603
# 7727      2525603
# 7728      2395082
# 7729      2395082
# 7730      2618603
# 7731      2618603
# 7732      2600940
# 7733      2600940
# 7734      2600756
# 7735      2511330
# 7736      2511330
# 7737      2516564
# 7738      2516564
# 7740      2494594
# 7741      2494594
# 7742      2516563
# 7743      2516563
# 7745      2111630
# 7746      2111630
# 7747      2370247
# 7748      2370247
# 7749      2632421
# 7750      2511331
# 7751      2511331
# 7752      2494586
# 7753      2494586
# 7754      2113845
# 7755      2113845
# 7763      2510540
# 7764      2603414
# 7765      2510542
# 7766      2618579
# 7767      2618578
# 7770      2618580
# 7791      2621626
# 7792      2621639
# 7801      2618183
# 7802      2618181
# 7803      2618180
# 7804      2618181
# 7805      2618179
# 7806      2620509
# 7807      2618180
# 7808      2618178
# 7809      2618179
# 7810      2618177
# 7811      2618178
# 7812      2618177
# 7836      2605086
# 7895      2622040
# 7896      2622039
# 7897      2622038
# 7898      2622037
# 7899      2622035
# 7900      2622034
# 7901      2622033
# 7902      2622032
# 7903      2622031
# 7905      2622030
# 7906      2600747
# 7908      2581772
# 7909      2605108
# 7910      2605108
# 7911      2605093
# 7912      2605093
# 7913      2600403
# 7914      2600403
# 7915      2605107
# 7916      2605107
# 7917      2541764
# 7918      2541764
# 7919      2600555
# 7920      2600555
# 7921      2600402
# 7922      2600402
# 7923      2600557
# 7924      2600557
# 7925      2600554
# 7926      2600554
# 7927      2541947
# 7928      2541947
# 7942      2620509
# 7985      2622028
# 8018      2622027
# 8022      2510542
# 8023      2510540
# 8024      2584842
# 8025      2525401
# 8043      2618596
# 8044      2618595
# 8045      2618603
# 8050      2618602
# 8051      2618599
# 8052      2618600
# 8151      2605086
# 8152      2605086
# 8167      2612512
# 8168      2621625
# 8174      2621604
# 8186      2612513
# 8195      2544053
# 8196      2544053
# 8199      2544051
# 8200      2544051
# 8201      2618578
# 8202      2618580
# 8203      2618579
# 8208      2544047
# 8216      2544038
# 8225      2618194
# 8238      2621226
# 8239      2621041
# 8241      2618598
# 8248      2612780
# 8250      2618196
# 8251      2621226
# 8252      2621226
# 8260      2618196
# 8261      2605044
# 8268      2605084
# 8285      2549666
# 8299      2590203
# 8302      2605081
# 8304      2618154
# 8315      2621041
# 8320      2582589
# 8321      2582589
# 8324      2618151
# 8325      2618149
# 8336      2618193
# 8352      2618606
# 8355      2620203
# 8372      2618606
# 8373      2620364
# 8375      2620203
# 8382      2620364
# 8383      2620364
# 8392      2620364
# 8430      2605110
# 8431      2605046
# 8444      2618177
# 8445      2618176
# 8446      2618175
# 8450      2618607
# 8452      2544039
# 8457      2618607
# 8459      2618157
# 8461      2605087
# 8473      2618192
# 8495      2618156
# 8496      2618189
# 8498      2605048
# 8505      2618190
# 8512      2612746
# 8513      2605080
# 8519      2605080
# 8520      2612746
# 8560      2448815
# 8561      2609802
# 8562      2609800
# 8563      2609803
# 8564      2609801
# 8567      2544049
# 8570      2441947
# 8571      2525726
# 8572      2609365
# 8573      2609363
# 8574      2609364
# 8584      2535302
# 8607      2609190
# 8608      2609189
# 8609      2609188
# 8610      2610947
# 8611      2609181
# 8612      2601143
# 8613      2177243
# 8614      2601152
# 8615      2402063
# 8616      2177242
# 8617      2220048
# 8618      2525710
# 8619      2583130
# 8620      2583128
# 8621      2583127
# 8622      2543856
# 8623      2583126
# 8636      2600757
# 8637      2583735
# 8638      2585003
# 8639      2547793
# 8685      2106122
# 8732      2062372
# 8733      2512328
# 8734      1888822
# 8736      2363964
# 8739      2371376
# 8740      2418851
# 8743      2418961
# 8746      2371377
# 8747      2457833
# 8748      2019058
# 8749      2069170
# 8753      2364054
# 8754      2363964
# 8755      2418961
# 8756      2371376
# 8757      2069170
# 8758      2512328
# 8759      1888822
# 8760      2371377
# 8761      2062372
# 8765      2019058
# 8766      2457833
# 8770      2418851
# 8772      2364054
# 8773      2363964
# 8774      2418961
# 8778      2371376
# 8779      2069170
# 8780      2512328
# 8781      1888822
# 8782      2371377
# 8783      2062372
# 8787      2019058
# 8788      2457833
# 8792      2418851
# 8794      2364054
# 8795      2363964
# 8796      2418961
# 8797      2371376
# 8798      2069170
# 8799      2512328
# 8800      1888822
# 8801      2371377
# 8802      2062372
# 8806      2019058
# 8807      2457833
# 8811      2418851
# 8817      2364054
# 8818      2363964
# 8819      2418961
# 8820      2371376
# 8821      2069170
# 8822      2512328
# 8823      1888822
# 8824      2371377
# 8825      2062372
# 8829      2019058
# 8830      2457833
# 8834      2418851
# 8836      2364054
# 8837      2363964
# 8838      2418961
# 8839      2371376
# 8840      2605100
# 8844      2069170
# 8845      2512328
# 8853      2612380
# 8854      2605097
# 8855      2605095
# 8857      2590225
# 8866      1888822
# 8867      2371377
# 8868      2062372
# 8873      2418851
# 8875      2364054
# 8877      2102220
# 8879      2494593
# 8881      2243022
# 8882      2156445
# 8883      2396859
# 8885      2019058
# 8886      2457833
# 8888      2396859
# 8890      2243022
# 8891      2494593
# 8892      2156445
# 8893      2102220
# 8899      2396859
# 8901      2243022
# 8902      2494593
# 8903      2156445
# 8904      2102220
# 8907      2396859
# 8909      2243022
# 8910      2494593
# 8911      2156445
# 8912      2102220
# 8915      2396859
# 8917      2243022
# 8926      2494593
# 8927      2156445
# 8928      2102220
# 8931      2396859
# 8933      2243022
# 8934      2494593
# 8935      2156445
# 8936      2102220
# 8977      2525513
# 8986      2609580
# 8987      2609582
# 8989      2609583
# 8990      2609584
# 8991      2612592
# 8993      2609580
# 8994      2609582
# 8995      2609583
# 8996      2609584
# 8997      2605109
# 8998      2605089
# 9003      2612592
# 9060      2605045
# 9076      2605045
# 9078      2605047
# 9079      2605045
# 9080      2605045
# 9082      2605045
# 9083      2605045
# 9084      2605045
# 9089      2605047
# 9090      2605083
# 9106      2605083
# 9107      2605090
# 9109      2605085
# 9111      2605079
# 9112      2605085
# 9117      2605092
# 9118      2600553
# 9119      2605079
# 9120      2605079
# 9121      2605079
# 9132      2605093
# 9136      1341547
# 9141      2492098
# 9147      2492098
# 9148      2457816
# 9149      2457816
# 9150      2470210
# 9151      2470210
# 9152      2469972
# 9153      2469972
# 9155      2600936
# 9156      1341555
# 9159      2600936
# 9166      2605098
# 9276      2544019
# 9285      2605094
# 9287      2605102
# 9288      2605101
# 9290      2590231
# 9301      2605105
# 9306      2605104
# 9311      2605106
# 9337      2541765
# 9341      2541765
# 9346      2605040
# 9363      2603413
# 9365      2605043
# 9368      2605091
# 9389      2605088
# 9390      2605107
# 9421      2590209
# 9427      2590209
# 9433      2605108
# 9452      2605041
# 9464      2590209
# 9470      2590209
# 9503      2594058
# 9545      2582375
# 9546      2582381
# 9550      2416191
# 9551      2592795
# 9552      2600940
# 9553      2600941
# 9554      2600939
# 9555      2600942
# 9556      2600943
# 9557      2395082
# 9558      2525603
# 9559      2600745
# 9562      2600745
# 9623      2547795
# 9624      2547792
# 9625      2547794
# 9672      2592795
# 9673      2541764
# 9692      2416191
# 9693      2604874
# 9699      2604877
# 9700      2600559
# 9701      2590250
# 9702      2600558
# 9703      2600405
# 9720      2582381
# 9725      2582375
# 9731      2549668
# 9737      2549654
# 9738      2549653
# 9739      2600407
# 9740      2600411
# 9741      2600406
# 9742      2600410
# 9743      2600565
# 9744      2600567
# 9747      2549672
# 9748      2549667
# 9758      2547643
# 9759      2600404
# 9762      2600399
# 9775      2540663
# 9776      2547646
# 9790      2549669
# 9791      2549670
# 9824      2547650
# 9826      2590207
# 9840      1091882
# 9856      2600569
# 9857      2600571
# 9859      2600571
# 9861      2600400
# 9869      2594060
# 9925      2600571
# 9951      2594059
# 9965      2600569
# 10043     2543854
# 10054     2583126
# 10055     2600557
# 10056     2583126
# 10057     2594061
# 10058     2493148
# 10059     2493148
# 10060     2583125
# 10061     2583125
# 10066     2600556
# 10074     2219886
# 10084     2600560
# 10096     2219886
# 10101     2559471
# 10102     2559471
# 10116     2600561
# 10121     2600554
# 10133     2600564
# 10139     2600402
# 10153     2600401
# 10158     2600398
# 10168     2600412
# 10171     2600555
# 10172     2600562
# 10176     2600413
# 10177     2600409
# 10181     2600552
# 10186     2600398
# 10190     2441850
# 10203     2592631
# 10204     2592632
# 10206     2592796
# 10235     2600403
# 10236     2600551
# 10249     2441917
# 10281     2206023
# 10282     2592797
# 10283     2592797
# 10284     2592957
# 10292     2592955
# 10303     2543586
# 10304     2543585
# 10305     2543583
# 10315     2592956
# 10319     2592632
# 10329     2592631
# 10330     2592631
# 10331     2592796
# 10332     2592796
# 10356     2590228
# 10357     2581564
# 10358     2593891
# 10360     2592952
# 10375     2585011
# 10400     2582373
# 10401     2582378
# 10404     2582382
# 10406     2582383
# 10427     2582378
# 10428     2582383
# 10429     2582382
# 10430     2582373
# 10450     2590251
# 10459     2549665
# 10460     2590205
# 10461     2541941
# 10462     2541942
# 10487     2590254
# 10489     1341554
# 10491     1341546
# 10511     2590253
# 10533     2590223
# 10557     2549652
# 10559     2590233
# 10560     2590217
# 10561     2590210
# 10562     2549648
# 10606     2258816
# 10612     2591653
# 10625     2590206
# 10636     2543726
# 10654     2581573
# 10656     2258817
# 10660     2590248
# 10679     1107971
# 10682     2549639
# 10684     2590252
# 10688     2558112
# 10691     2457835
# 10692     2457835
# 10693     2418965
# 10694     2418965
# 10711     2549663
# 10719     2590247
# 10723     2361253
# 10730     2557393
# 10731     2558116
# 10732     2590249
# 10733     2558110
# 10735     2541947
# 10741     2541948
# 10751     2549664
# 10757     2541949
# 10799     1665046
# 10800     1665046
# 10801     1665046
# 10804     1665046
# 10806     2558991
# 10809     2582386
# 10810     2582385
# 10811     2582384
# 10812     2582391
# 10813     2582390
# 10814     2582392
# 10836     2558991
# 10847     2582376
# 10848     2582379
# 10853     2582380
# 10854     2558990
# 10857     2558990
# 10866     2394473
# 10868     2547338
# 10897     2581946
# 10899     2543587
# 10900     2470697
# 10913     2581577
# 10914     2581578
# 10932     2581948
# 10941     2581950
# 11002     2244054
# 11004     2549645
# 11005     2584903
# 11006     2581949
# 11014     2394473
# 11020     2581951
# 11026     2581575
# 11027     2244055
# 11028     2556833
# 11031     2581565
# 11046     2540661
# 11048     2559471
# 11056     2582380
# 11058     2582379
# 11059     2582376
# 11060     2584810
# 11061     2584809
# 11062     2581567
# 11065     2582589
# 11077     2544037
# 11095     2581574
# 11105     2581576
# 11155     2583442
# 11158     2540671
# 11159     2581563
# 11177     2581569
# 11178     2583123
# 11179     2470910
# 11183     2543724
# 11193     2546523
# 11194     2581761
# 11213     2581761
# 11242     2549661
# 11306     2583443
# 11307     2439143
# 11332     2581572
# 11333     2581560
# 11347     2546523
# 11352     2581561
# 11356     2581559
# 11358     2546524
# 11362     2581562
# 11365     2546524
# 11366     2546524
# 11372     2581566
# 11373     2535524
# 11374     2549650
# 11375     2549651
# 11376     2547346
# 11377     2547342
# 11378     2549647
# 11379     2549655
# 11380     2549656
# 11381     2549649
# 11387     2525708
# 11391     2525707
# 11400     2525706
# 11401     2525704
# 11402     2525705
# 11403     2525709
# 11404     2525721
# 11416     2558982
# 11417     2558984
# 11418     2558983
# 11448     2547357
# 11459     2070687
# 11461     1764500
# 11474     2244169
# 11475     2244169
# 11476     2541952
# 11477     2541952
# 11478     2244171
# 11479     2244171
# 11480     2546327
# 11481     2546327
# 11482     2457294
# 11483     2457294
# 11484     2373409
# 11485     2373409
# 11488     2559463
# 11489     2559464
# 11490     2559627
# 11491     2332277
# 11492     2418884
# 11513     2556832
# 11514     2543628
# 11515     2543627
# 11516     2543626
# 11517     2543625
# 11518     2543629
# 11542     2178763
# 11543     2178763
# 11599     2549676
# 11604     2549676
# 11606     2470703
# 11607     2470696
# 11608     2070687
# 11609     2070687
# 11610     2543592
# 11611     2543593
# 11613     2543591
# 11614     1764500
# 11645     2557946
# 11646     2557940
# 11647     2557943
# 11649     2558878
# 11652     2558878
# 11653     2543727
# 11685     2418884
# 11713     2544862
# 11714     2543728
# 11715     2543723
# 11716     2525599
# 11742     2558108
# 11744     2559444
# 11748     2557016
# 11749     2548853
# 11750     2548852
# 11751     2548770
# 11766     2549638
# 11767     2549644
# 11832     2401792
# 11871     2549676
# 11873     2549674
# 11876     2549677
# 11877     2546330
# 11878     2558111
# 11879     2549686
# 11895     2559224
# 11896     2549673
# 11911     2549660
# 11915     2558111
# 11925     2549674
# 11926     2549676
# 11928     2549677
# 11935     2549640
# 11939     2546330
# 11974     2549688
# 11979     2401792
# 11982     2549643
# 12016     2549646
# 12020     2369257
# 12037     2549642
# 12039     2549224
# 12040     2549120
# 12041     2556682
# 12053     2558115
# 12055     2549641
# 12066     2480774
# 12067     2182591
# 12068     2549658
# 12082     2549671
# 12083     2549710
# 12092     2549659
# 12101     2547353
# 12115     2525722
# 12117     2525711
# 12118     2525712
# 12119     2525714
# 12121     2525715
# 12132     2401709
# 12133     2329097
# 12134     2525700
# 12135     2525724
# 12136     2525725
# 12137     2546291
# 12138     2546290
# 12142     2548768
# 12146     2547524
# 12147     2547525
# 12148     2547526
# 12149     2070886
# 12150     2070885
# 12151     2547520
# 12159     2549636
# 12160     2549637
# 12161     2549556
# 12168     2549637
# 12171     2549636
# 12179     2547353
# 12180     2070886
# 12181     2070885
# 12182     2547520
# 12254     2547319
# 12262     2546467
# 12263     2546467
# 12269     2547526
# 12277     2547525
# 12279     2547524
# 12283     2549586
# 12316     2547354
# 12318     2547352
# 12322     2547341
# 12323     2547345
# 12324     2547340
# 12325     2547320
# 12326     2547318
# 12329     2244169
# 12331     2244171
# 12333     2244171
# 12335     2547317
# 12336     2244169
# 12337     2547355
# 12346     2547356
# 12353     2547321
# 12440     2361256
# 12441     1585194
# 12443     2547349
# 12479     1585195
# 12488     2547315
# 12507     1880727
# 12508     1880727
# 12509     1880727
# 12510     1880727
# 12528     2547316
# 12534     2408812
# 12537     2547314
# 12540     2547351
# 12541     2547339
# 12553     2547348
# 12557     2547343
# 12570     1973519
# 12571     1973519
# 12572     1973519
# 12573     1538404
# 12574     1538404
# 12575     1538404
# 12576     1538404
# 12577     1983739
# 12578     1983739
# 12579     1983739
# 12580     1983739
# 12581     1840779
# 12582     1840779
# 12583     1840779
# 12584     1973327
# 12585     1973327
# 12586     1973327
# 12587     1971874
# 12588     1971874
# 12589     1971874
# 12590     1954819
# 12591     1954819
# 12592     1954819
# 12593     1971871
# 12594     1971871
# 12595     1971871
# 12596     1971872
# 12597     1971872
# 12598     1971872
# 12599     1971875
# 12600     1971875
# 12601     1971875
# 12602      650219
# 12603      650219
# 12604      650219
# 12605     1780611
# 12606      642463
# 12607      642463
# 12608      642463
# 12609      642463
# 12610      642463
# 12611     1694451
# 12625     1780234
# 12627     1194539
# 12628     1194539
# 12629     1194539
# 12630     1194539
# 12631     1194539
# 12632     1194539
# 12633     1194539
# 12634     1194539
# 12635     1194539
# 12636     1194539
# 12637     1194539
# 12638     1194539
# 12639     1195190
# 12640     1195190
# 12641     1195190
# 12642     1195190
# 12643     1195190
# 12644     1195190
# 12645     1033729
# 12646     1033729
# 12647     1033729
# 12648     1033729
# 12649     1033729
# 12650     1033729
# 12651     1006170
# 12652     1006170
# 12653     1006170
# 12654     1006170
# 12655     1006170
# 12656     1006170
# 12666     2068872
# 12667     2068872
# 12683     2547344
# 12696     2547446
# 12720     2543858
# 12727     2547347
# 12729     2547441
# 12732     2547350
# 12738     2438722
# 12748     2543857
# 12775     2441915
# 12776     2543734
# 12783     2546329
# 12795     2546329
# 12809     2546019
# 12812     2540664
# 12813     2540673
# 12814     2541597
# 12815     2525593
# 12816     2543729
# 12817     2470699
# 12818     2470700
# 12819     2470702
# 12820     2470698
# 12858     2541954
# 12861     2543734
# 12862     2541969
# 12878     2541962
# 12880     2541938
# 12903     2441915
# 12913     2441915
# 12914     2441915
# 12915     2441915
# 12916     2441915
# 12922     2541972
# 12923     2536472
# 12924     2536472
# 12946     2541960
# 12951     2371360
# 12953     2371360
# 12958     2469943
# 12960     2546327
# 12962     2373405
# 12963     2541971
# 12964     2543523
# 12965     2543523
# 12966     2470205
# 12969     2416710
# 12970     2540677
# 12971     2540676
# 12972     2540674
# 12973     2540675
# 12974     2373405
# 12978     2541963
# 13005     2543522
# 13007     2541970
# 13008     2373406
# 13010     2373406
# 13038     2541955
# 13046     2543735
# 13055     2543736
# 13072     2541627
# 13101     2541953
# 13106     2525513
# 13107     2525513
# 13117     2541956
# 13122     2394477
# 13135     2541968
# 13145     2543736
# 13148     2543735
# 13158     2541968
# 13169     2541967
# 13171     2541627
# 13181     2541952
# 13183     2242097
# 13185     2242097
# 13208     2541959
# 13209     2541964
# 13210     2540662
# 13211     2543855
# 13218     2541630
# 13219     2541950
# 13221     2541630
# 13226     2541629
# 13227     2541966
# 13231     2541951
# 13243     2541629
# 13245     2541628
# 13271     2541628
# 13272     2541958
# 13318     2535290
# 13319     2535291
# 13320     2536168
# 13321     2373401
# 13322     2536470
# 13323     2536471
# 13333     2540660
# 13335     2540659
# 13340     2493147
# 13342     2511330
# 13349     2416709
# 13350     2525611
# 13351     2481700
# 13353     2481711
# 13354     2535528
# 13358     2536470
# 13359     2536471
# 13406     2540665
# 13407     2540667
# 13408     2540666
# 13409     2516729
# 13410     2516730
# 13411     2516728
# 13412     2516727
# 13415     2470701
# 13416     2449317
# 13417     2449315
# 13427     2540670
# 13428     2540669
# 13429     2492290
# 13488     2539775
# 13490     2535418
# 13493     2535522
# 13500     2535527
# 13504     2535413
# 13519     2472527
# 13520     2373401
# 13521     2539783
# 13525     2535411
# 13526     2541539
# 13535     2535414
# 13541     2540400
# 13544     2539782
# 13545     2503761
# 13546     2503761
# 13547     2492734
# 13550     2457315
# 13551     2510401
# 13552     2541538
# 13555     2516585
# 13570     2535416
# 13573     2541519
# 13601     2535419
# 13603     2457319
# 13606     2457318
# 13627     2492288
# 13628     2492287
# 13629     2492289
# 13637     2457289
# 13649     2525399
# 13651     2540656
# 13678     2540391
# 13722     2539778
# 13727     2401710
# 13728     2401710
# 13744     2457294
# 13753     2539779
# 13757     2540390
# 13758     2540392
# 13761     2364057
# 13777     2535530
# 13782     2535420
# 13791     2539780
# 13795     2535415
# 13796     2535529
# 13799     2369057
# 13800     2492735
# 13801     2510979
# 13903     2516597
# 13915     2449316
# 13917     2449309
# 13918     2449310
# 13919     2449318
# 13920     2449314
# 13921     2525605
# 13922     2525602
# 13961     2480561
# 13962     2535304
# 13963     2535305
# 13967     2535303
# 13986     2535526
# 13988     2525604
# 13989     2373409
# 14010     2536168
# 14011     2535520
# 14021     2535521
# 14042     2535291
# 14043     2535290
# 14076     2535525
# 14078     2535525
# 14084     2535523
# 14089     2525720
# 14106     2525719
# 14107     2525718
# 14108     2525717
# 14109     2525719
# 14110     2525720
# 14111     2525718
# 14112     2525717
# 14118     2525699
# 14125     2525723
# 14158     2525716
# 14159     2525596
# 14160     2525594
# 14161     2525600
# 14162     2525598
# 14223     2525513
# 14255     2373824
# 14287     2477570
# 14288     2373822
# 14289     2525400
# 14294     2516740
# 14296     2516740
# 14321     2520281
# 14322     2520281
# 14323     2520281
# 14324     2520281
# 14325     2520281
# 14326     2520281
# 14327     2520281
# 14328     2520281
# 14329     2520281
# 14330     2520281
# 14331     2370870
# 14357     2516595
# 14358     2516592
# 14364     2516587
# 14374     2516596
# 14377     2516584
# 14389     2516588
# 14400     2516565
# 14401     2516563
# 14402     2516568
# 14403     2516562
# 14404     2516567
# 14405     2494553
# 14406     2494553
# 14407     2493151
# 14408     2493151
# 14409     2180113
# 14410     2501274
# 14411     2501274
# 14414     2516564
# 14415     2516570
# 14416     2516569
# 14424     2449313
# 14437     2516435
# 14442     2516298
# 14446     2516432
# 14453     2516430
# 14465     2493149
# 14466     2510980
# 14467     2494593
# 14468     2494594
# 14477     2492279
# 14487     2111630
# 14494     2492278
# 14495     2516434
# 14496     2516433
# 14497     2516431
# 14499     2449320
# 14500     2516737
# 14501     2308344
# 14577     2516297
# 14579     2516184
# 14584     2516185
# 14622     2513731
# 14624     2513730
# 14625     2513731
# 14641     2513730
# 14656     2457311
# 14660     2513729
# 14663     2513729
# 14712     2510541
# 14717     2492733
# 14722     2501272
# 14724     2501271
# 14725     2494554
# 14726     2494595
# 14727     2494557
# 14729     2494556
# 14732     2511163
# 14734     2511168
# 14744     2502121
# 14745     2511332
# 14776     2457290
# 14777     2457290
# 14778     2481716
# 14779     2493381
# 14780     2481715
# 14781     2481714
# 14782     2481713
# 14783     2457285
# 14784     2457285
# 14785     2373408
# 14786     2373408
# 15039     2364061
# 15040     2364061
# 15042     2438742
# 15043     2438742
# 15044     2240232
# 15045     2240232
# 15046     2418850
# 15047     2418850
# 15048     2258830
# 15049     2258830
# 15050     2065944
# 15051     2065944
# 15065     2513485
# 15078     2480643
# 15079     2156445
# 15080     2510541
# 15102     2510533
# 15131     2510535
# 15142     2183179
# 15143     2183179
# 15163     2501734
# 15164     2501734
# 15165     2501734
# 15205     2510538
# 15206     2307820
# 15207     2307820
# 15208     2504122
# 15212     2480816
# 15213     2480807
# 15214     2307915
# 15216     2311579
# 15219     2309396
# 15220     2309396
# 15221     2257340
# 15222     2257342
# 15224     2510536
# 15225     2311166
# 15226     2512328
# 15228     2332362
# 15229     2183186
# 15230     2307833
# 15238     2307909
# 15240     2333786
# 15251     2492571
# 15252     2492571
# 15253     2492571
# 15254     2510534
# 15255     2492571
# 15256     2332263
# 15257     2480807
# 15258     2480816
# 15259     2480816
# 15260     2480807
# 15265     2228949
# 15266     2228949
# 15269     2360829
# 15271     2257196
# 15273     2257196
# 15274     2257196
# 15303     2510537
# 15367     2360829
# 15376     2510400
# 15378     2480838
# 15384     2503692
# 15385     2503692
# 15386     2480838
# 15387     2480838
# 15404     2502668
# 15405     2502666
# 15407     2502667
# 15408     2502669
# 15462     2511331
# 15464     2284049
# 15465     2511335
# 15466     2511334
# 15467     2511333
# 15468     2511333
# 15488     2370247
# 15489     2113262
# 15493     2229064
# 15494     2229064
# 15495     2332212
# 15498     2332212
# 15499     2492284
# 15507     2328591
# 15583     2309405
# 15585     2309405
# 15586     2183025
# 15588     2244441
# 15589     2244046
# 15590     2304088
# 15591     2244046
# 15592     1140874
# 15597     2244046
# 15598     2244046
# 15600     1996023
# 15601     1983737
# 15602     2244046
# 15609     2311308
# 15617     2361865
# 15626     1410805
# 15627     1410805
# 15628     1410805
# 15629     1410805
# 15632     2369609
# 15637     2294420
# 15639     2369609
# 15645     2369609
# 15678     1575431
# 15679     1575431
# 15688     2510399
# 15689     2062363
# 15693     2062363
# 15702     2062363
# 15703     2062363
# 15706     2510399
# 15716     2494558
# 15717     2494585
# 15720     2494587
# 15721     2494586
# 15722     2494588
# 15723     2494551
# 15724     2494550
# 15725     2494589
# 15729     2503739
# 15750     2501075
# 15752     2501076
# 15753     2501077
# 15754     2501080
# 15755     2501079
# 15756     2501082
# 15757     2470215
# 15802     2480647
# 15803     2501258
# 15804     2501263
# 15805     2501260
# 15806     2501261
# 15807     2501257
# 15808     2501256
# 15809     2501259
# 15810     1971330
# 15811     2480646
# 15812     2480644
# 15813     2113845
# 15814      645497
# 15815     2102226
# 15816     2057629
# 15817     2480645
# 15924     2481597
# 15959     2409313
# 15976     2502545
# 16332     2311310
# 16335     2480842
# 16338     2492293
# 16339     2492569
# 16340     2492269
# 16341     2492571
# 16369     2244439
# 16390     2492106
# 16391     2492105
# 16392     2492108
# 16394     2492569
# 16395     2492571
# 16489     2494555
# 16490     2494590
# 16491     2494592
# 16492     2494552
# 16493     2494591
# 16539     2449312
# 16545     2493030
# 16553     2492583
# 16554     2492739
# 16557     2244439
# 16558     2480842
# 16559     2492293
# 16560     2492269
# 16565     2332453
# 16591     2477768
# 16592     2477769
# 16754     2480735
# 16769     2494549
# 16772     2449319
# 16914     2492094
# 16915     2492104
# 16916     2492098
# 16917     2492100
# 16918     2492097
# 16931     2477767
# 16966     2477763
# 16974     2477765
# 16996     2369613
# 17000     2480560
# 17001     2480560
# 17002     2492286
# 17010     2492285
# 17057     2477948
# 17058     2418961
# 17059     2457816
# 17066     2480777
# 17067     2480861
# 17069     2480776
# 17073     2477761
# 17074     2477760
# 17075     2477762
# 17076     2371394
# 17077     2356356
# 17105     2480700
# 17106     2480726
# 17109     2394474
# 17110     2480734
# 17181     2481697
# 17184     2481656
# 17185     2363755
# 17206     2480861
# 17208     2480861
# 17230     2480861
# 17232     2480861
# 17233     2480861
# 17250     2481598
# 17252     2480861
# 17253     2480861
# 17256     2480861
# 17257     2480861
# 17258     2480861
# 17259     2480861
# 17272     2481599
# 17276     2480861
# 17277     2480861
# 17278     2480861
# 17279     2480861
# 17280     2480861
# 17281     2480861
# 17283     2480861
# 17292     2480777
# 17293     2480776
# 17315     2477569
# 17317     2461465
# 17360     2481655
# 17367     2457817
# 17405     2394474
# 17406     2394474
# 17413     2480669
# 17417     2477949
# 17418     2477953
# 17419     2477952
# 17420     2477951
# 17421     2457815
# 17432     2477593
# 17433     2477592
# 17434     2477590
# 17435     2477589
# 17436     2477591
# 17437     2477594
# 17438     2477588
# 17530     2480835
# 17531     2480642
# 17532     2480560
# 17537     2480834
# 17538     2438677
# 17539     2477375
# 17540     2480641
# 17541     2480638
# 17554     2457313
# 17557     2480734
# 17558     2480637
# 17573     2480726
# 17575     2480635
# 17576     2480636
# 17578     2480639
# 17581     2477375
# 17584     2479442
# 17586     2480640
# 17588     2480700
# 17592     2477377
# 17594     2477378
# 17595     2470458
# 17600     2213898
# 17605     2477376
# 17606     2457303
# 17607     2477369
# 17608     2477369
# 17612     2373704
# 17614     2473147
# 17619     2373395
# 17620     2459773
# 17622     2480563
# 17631     2394475
# 17638     2213899
# 17666     2394475
# 17672     2473002
# 17673     2477380
# 17681     2473097
# 17682     2448577
# 17699     2473002
# 17733     2477380
# 17761     2458983
# 17762     2458983
# 17770     2457288
# 17779     2126460
# 17789     2470226
# 17791     2478579
# 17810     2478579
# 17813     2470211
# 17815     2477370
# 17821     2472175
# 17846     2470210
# 17847     2470216
# 17849     2472175
# 17850     2472175
# 17852     2477766
# 17856     2477367
# 17868     2457287
# 17873     2477764
# 17879     2473070
# 17895     2477371
# 17898     2477372
# 17901     2477374
# 17949     2477368
# 17950     2416329
# 17953     2477373
# 17955     2470694
# 17956     2470466
# 17958     2220044
# 17959     2470465
# 17960     2470464
# 17962     2470467
# 17967     2473036
# 17987     2448803
# 17988     2461477
# 17989     2448804
# 18000     2457329
# 18001     2470472
# 18049     2449538
# 18050     2449536
# 18051     2416445
# 18052     2461541
# 18056     2448804
# 18061     2448803
# 18065     2461477
# 18070     2470461
# 18075     2470456
# 18082     2126462
# 18089     2470457
# 18094     2472174
# 18095     2473094
# 18097     2457290
# 18098     2448805
# 18099     2470462
# 18103     2471880
# 18118     2471714
# 18119     2470472
# 18121     2472982
# 18122     2470463
# 18123     2394476
# 18145     2472530
# 18324     2470222
# 18327     2416430
# 18328     2394480
# 18334     2461466
# 18339     2457329
# 18350     2457295
# 18356      892054
# 18357      864503
# 18358      864503
# 18360      864502
# 18361      815774
# 18362      840887
# 18363      685523
# 18364     2255509
# 18365      685515
# 18384      664981
# 18409      664766
# 18414      664766
# 18415      650930
# 18416     2470455
# 18418      650930
# 18419      650933
# 18420      650933
# 18426     2438716
# 18427     2457286
# 18428      650932
# 18431     1881878
# 18432     2469972
# 18433     2469975
# 18434     2469973
# 18435     2177157
# 18436     2469976
# 18437     2458983
# 18443     2470460
# 18451     2470459
# 18452     2438735
# 18463     2457325
# 18464     2457325
# 18497      566014
# 18498      557377
# 18499      593796
# 18500      615748
# 18501      615749
# 18502      626362
# 18503      639962
# 18504      639955
# 18505      661422
# 18506      642456
# 18507      664981
# 18508      645495
# 18509      650934
# 18510      650930
# 18511      650933
# 18512      664766
# 18515     2419678
# 18516     2419679
# ...
# 139782    1552462
# 139783    1552461
# 139784    1552385
# 139785    1547678
# 139787    1571877
# 139788    1561912
# 139792    1467037
# 139794    1552340
# 139797    1545448
# 139808    1570276
# 139813    1568372
# 139817    1470001
# 139822    1550116
# 139825    1470051
# 139830    1564820
# 139832     685523
# 139835     685515
# 139836    1575417
# 139837    1564387
# 139842    1564818
# 139843    1550117
# 139844    1550737
# 139845     682744
# 139846    1550737
# 139849    1539562
# 139850    1545438
# 139851     680676
# 139852    1545438
# 139853    1550732
# 139854    1550732
# 139858    1550472
# 139859    1462329
# 139860    1550478
# 139861     645480
# 139862    1547270
# 139871    1547270
# 139872    1451833
# 139874     650930
# 139878     650934
# 139881    1539302
# 139883    1550847
# 139892     879131
# 139893     647392
# 139894    1561914
# 139897     664981
# 139898    1564821
# 139902     664766
# 139904     645477
# 139908    1550739
# 139911     655686
# 139917     655679
# 139921     650499
# 139923    1489528
# 139933     642456
# 139940    1561924
# 139942    1561971
# 139946     661422
# 139951    1550472
# 139953     659375
# 139954    1579293
# 139959     655687
# 139963    1557669
# 139964    1561970
# 139966    1564386
# 139967    1550478
# 139968     647419
# 139969    1550478
# 139970    1550478
# 139971     655682
# 139972    1550478
# 139973     647420
# 139974    1575426
# 139980    1550478
# 139981     645484
# 139983    1561927
# 139984    1550478
# 139994    1550478
# 139995    1550478
# 139996     645495
# 139997    1575948
# 140002    1575410
# 140003    1575798
# 140005    1550478
# 140006    1550478
# 140007    1550478
# 140009     650213
# 140014     650209
# 140017     650933
# 140019     593796
# 140024     566014
# 140025     647391
# 140027    1564384
# 140030    2183113
# 140031     647393
# 140034    1575801
# 140036    1575418
# 140037    1557670
# 140041     647393
# 140044    1564388
# 140049     642453
# 140052    1564381
# 140054     642453
# 140057    2186716
# 140060    2186759
# 140063    1564388
# 140069    2186717
# 140074    1561915
# 140076    2186741
# 140078    1564388
# 140082    1561968
# 140083    2186715
# 140086    2186714
# 140093    1557668
# 140097    1564368
# 140101    1545443
# 140102    1543987
# 140108    1564383
# 140109    1564369
# 140111    1550969
# 140112    1564370
# 140116    1575802
# 140125    1547680
# 140126    1575419
# 140132    1575394
# 140136    1418919
# 140146    1545443
# 140151    1550267
# 140163    1557670
# 140168    1575436
# 140174    1564382
# 140193    1550265
# 140194    1547681
# 140198    1547681
# 140203    1547710
# 140210    1560279
# 140215    1550266
# 140225    1387058
# 140228    1545541
# 140229    1575800
# 140230    1575397
# 140240    1576564
# 140252    1557673
# 140253    1557673
# 140254    1561967
# 140260    1558870
# 140261    1558870
# 140262    1564841
# 140264    1558870
# 140276    2127754
# 140281    2127754
# 140285    1561929
# 140287    1537878
# 140294    1575441
# 140302    1579291
# 140312    1564305
# 140325    1547677
# 140328    1561913
# 140329    2187582
# 140334    2186532
# 140336    1576562
# 140341    1575396
# 140351    2178707
# 140352    1550265
# 140353    1547711
# 140354    1547705
# 140355    1547684
# 140356    1496127
# 140360    1575792
# 140364    2183112
# 140365    1496124
# 140367    2185393
# 140368    1496124
# 140371    1545539
# 140372    1547682
# 140373    1673034
# 140383    1653764
# 140389    1575793
# 140392    1575949
# 140420    1575794
# 140421    1575443
# 140425    1207874
# 140431    1575399
# 140435    2183100
# 140440    2178419
# 140451    1576564
# 140463    1564835
# 140466    2183121
# 140469    1545440
# 140471    1545441
# 140473    1545439
# 140475    2209053
# 140477    2183115
# 140483    1545437
# 140484    1564819
# 140485    1575950
# 140487    1545435
# 140489    1576562
# 140492    1564819
# 140494    1545436
# 140495    2183115
# 140497    1539565
# 140502    1547683
# 140519    1545537
# 140525    1545529
# 140552    1564390
# 140558    1564390
# 140559    1575442
# 140569    1543986
# 140571    1537576
# 140572    1470080
# 140580    1564392
# 140581    1575445
# 140589    1331886
# 140592    1547153
# 140595    1547152
# 140596    1547154
# 140597    1575398
# 140598    1575416
# 140604    1564392
# 140605    1575434
# 140610    1545452
# 140612    1575440
# 140617    1578278
# 140627    1579288
# 140629    1578278
# 140632    1564838
# 140643    1547156
# 140644    1547156
# 140646    1547156
# 140651    1091905
# 140656    1550736
# 140666    1550738
# 140670    1550735
# 140675    1550733
# 140681    1517631
# 140687    1579298
# 140688    1579276
# 140690    1552256
# 140694    1552265
# 140701    1557682
# 140703    1579287
# 140704    1586752
# 140708    1552257
# 140709    1561913
# 140712    1561919
# 140715    1575400
# 140717    1552266
# 140718    1562055
# 140728    1552267
# 140729    1562055
# 140735    1552268
# 140736    1562137
# 140743    1552263
# 140744    1562137
# 140747    1562139
# 140754    1562139
# 140759    1562138
# 140767    1562138
# 140771    1562141
# 140775    1562141
# 140778    1547159
# 140793    1560356
# 140794    1559361
# 140795    1557672
# 140799    1561923
# 140800    1282947
# 140801    1557672
# 140804    1557672
# 140814    1575797
# 140828     925769
# 140831    1570275
# 140833    1504445
# 140838    1568365
# 140850    1568366
# 140881    1563833
# 140901    1535069
# 140904    2080326
# 140915    1571830
# 140917    1571832
# 140918    1375529
# 140919    1571834
# 140922    1888892
# 140926    1575795
# 140927    1570941
# 140932    1462340
# 140933    1571875
# 140939    1815086
# 140944    1575790
# 140945     776822
# 140946    1571871
# 140959    1462334
# 140960    1462341
# 140977    2070684
# 140980    1813259
# 140989    1579274
# 140990    1564852
# 141020    1571333
# 141022    1563832
# 141027    1571335
# 141034    1571336
# 141039    1571337
# 141043    1571334
# 141048    1564389
# 141054    1564391
# 141067    2178418
# 141070    1357951
# 141072    1557689
# 141079    2174027
# 141084    1517503
# 141086    2180390
# 141089    2180045
# 141099    2102225
# 141141    1547266
# 141144    1469276
# 141145    1545446
# 141146    1545446
# 141147    1547460
# 141152    1558011
# 141160    1561962
# 141169    1557685
# 141180    1517702
# 141184    1517702
# 141191    1579305
# 141205    2170512
# 141206    2183124
# 141209    1559361
# 141210    1560356
# 141213    1499463
# 141229    1577163
# 141234    1552337
# 141236    1577162
# 141259    1558009
# 141273    1557674
# 141275    1557690
# 141286    1557674
# 141288    1561932
# 141289    1561920
# 141291    1575407
# 141302    1560286
# 141305    1560392
# 141306    1561921
# 141308    1571876
# 141309    1571876
# 141311    1560285
# 141313    1563277
# 141314    1557684
# 141315    1560392
# 141318    1560287
# 141320    1571876
# 141321    1579267
# 141323    1560280
# 141326    1535071
# 141328    1579297
# 141333    1458471
# 141336    1464679
# 141340    1561922
# 141343    1543887
# 141345    1557997
# 141348    1558000
# 141353    1558001
# 141356    1535077
# 141359    1572293
# 141360    1572291
# 141361    1529404
# 141395    1558007
# 141419    1375529
# 141421    1562149
# 141423    1571327
# 141426    1575406
# 141442    1571339
# 141448    1572292
# 141451    1557530
# 141459    1557681
# 141460    1404910
# 141461    1557671
# 141485    1552537
# 141490    1552536
# 141491    1561931
# 141495    1560292
# 141499    1576566
# 141503    1579281
# 141523    1557671
# 141524    1557683
# 141536    1571830
# 141540    2070684
# 141550    1537441
# 141551    1462334
# 141552    1561973
# 141553    1537441
# 141557    1552259
# 141560    1561974
# 141561    1552259
# 141562    2080326
# 141563    1537441
# 141568    1552259
# 141570    1537441
# 141572    1552259
# 141573    1815086
# 141577    1552259
# 141583    1442943
# 141586    1442943
# 141588    1571834
# 141590    1552259
# 141591    1462341
# 141594    1442943
# 141598    1442943
# 141599    1552255
# 141600    1442943
# 141602    1579288
# 141607    1442943
# 141609    1571328
# 141610    1552255
# 141616    1552255
# 141617    1579281
# 141621    1571874
# 141622    1552255
# 141623    1552252
# 141625    1571872
# 141628    1552252
# 141630    1571873
# 141633    1571331
# 141637    1552255
# 141639    1552252
# 141640    1813259
# 141641    1552252
# 141642    1557527
# 141648    1552253
# 141649    1552252
# 141652    1552253
# 141654    1552253
# 141659    1552254
# 141660    1462340
# 141663    1571832
# 141664    1557677
# 141666    1552254
# 141668    1552254
# 141670    1552253
# 141676    1285074
# 141678    1552251
# 141683    1571329
# 141685    1552254
# 141688    1571340
# 141693    1285074
# 141695    1552251
# 141699    1285071
# 141700    1277397
# 141704     623192
# 141706    1560357
# 141707     999620
# 141710    1145295
# 141721    1562142
# 141725    1551273
# 141727    1579287
# 141730    1571831
# 141734    1571338
# 141738    1571330
# 141739    1571835
# 141750    1570275
# 141763    1888892
# 141774    1562140
# 141779    1568365
# 141786    2070684
# 141788    1462334
# 141790    2080326
# 141796    1568366
# 141810    1815086
# 141816    1462341
# 141831    1564839
# 141835    1564837
# 141841    1564836
# 141842    1570901
# 141846    1564856
# 141848    1564816
# 141852    1311650
# 141860    1564815
# 141863    1561917
# 141864    2207742
# 141865    1311650
# 141870    1564814
# 141876    1570941
# 141883    1561917
# 141884    1564813
# 141888    2183087
# 141890    1570941
# 141892    1570941
# 141895    1570941
# 141900    1558871
# 141903    1579290
# 141906    1570941
# 141907    1496128
# 141909    1552457
# 141913    1552457
# 141919    1552457
# 141920     623192
# 141925     623192
# 141927    1560357
# 141934    1575408
# 141980    1571833
# 141988    2207492
# 141992    2183113
# 142009    1575433
# 142010    1579301
# 142053    1576568
# 142056    2187037
# 142063    1550478
# 142064    1576572
# 142069    1576566
# 142095    2206032
# 142103    2180114
# 142105    1575405
# 142142    1577539
# 142143    1575415
# 142152     999620
# 142154    2208761
# 142182    1564827
# 142186    1564832
# 142190    1564831
# 142195    2206019
# 142206    1462341
# 142208    1564833
# 142220    1564828
# 142225    1564829
# 142226    1564826
# 142235    1557512
# 142252    1229196
# 142260    1208702
# 142261    1462343
# 142263    1557534
# 142273    1552635
# 142278    1575428
# 142283    2178760
# 142286    2182180
# 142291    2187046
# 142301    1557526
# 142302    2187045
# 142309    2206007
# 142312    1322346
# 142313    1322346
# 142317    1322346
# 142319    1535070
# 142321    1535070
# 142322    1535070
# 142325    1557838
# 142326    1557838
# 142328    1557838
# 142330    1557834
# 142333    1557834
# 142334    1557840
# 142336    1499462
# 142347    2182649
# 142352    2207138
# 142356    2207259
# 142363    2170509
# 142365    2186239
# 142380    2206739
# 142381    1246653
# 142382    1575411
# 142385    2206738
# 142412    1575451
# 142417    2185390
# 142419    1557535
# 142422    1564830
# 142423    1557514
# 142429    1575452
# 142437    1557678
# 142440     650930
# 142443    1557686
# 142446    1560858
# 142447    1564817
# 142448    1578116
# 142452    1557686
# 142454    1557686
# 142455    1568367
# 142456    1568369
# 142458    1560320
# 142461     650930
# 142462    1578476
# 142463     650930
# 142465    1561925
# 142466    1560320
# 142472    1575425
# 142473    1404904
# 142475    1563107
# 142478    1419327
# 142481    1557518
# 142485    1294430
# 142487    1564817
# 142489    1575422
# 142495    1560291
# 142499    1557678
# 142501    1557678
# 142512    1557678
# 142520    1557678
# 142526    1575424
# 142531    1535065
# 142533    1537310
# 142535    1535065
# 142536    1558527
# 142540    1408946
# 142554    1561934
# 142561    1560858
# 142570    1558527
# 142578    1575423
# 142589    1557679
# 142590    1557688
# 142597    1557688
# 142605    1557520
# 142606     650930
# 142609    1535064
# 142612    1557679
# 142615    1557679
# 142617    1557679
# 142623     650930
# 142625    1564857
# 142626    1557679
# 142627    1557679
# 142635    1568367
# 142639    1568370
# 142643    1228550
# 142653    1557680
# 142664    1568369
# 142666    1419325
# 142670    1557519
# 142672    1558174
# 142675    1557528
# 142680     650930
# 142686    1557523
# 142690    1558870
# 142699    1504441
# 142705    1557516
# 142708    1322292
# 142710    1561964
# 142721    1558870
# 142728    1499465
# 142729    1499465
# 142731    1518047
# 142735    1496117
# 142736    1496117
# 142738    1496116
# 142739    1496116
# 142741    1466041
# 142742    1466041
# 142745    1470021
# 142746    1470021
# 142751    1488984
# 142753    1488984
# 142755    1455188
# 142756    1455188
# 142760    1430575
# 142761    1430575
# 142764    1557532
# 142765    1564850
# 142770    1455176
# 142771    1455176
# 142772    1462385
# 142773    1462385
# 142774    1558693
# 142776    1462379
# 142777    1462379
# 142781    1558174
# 142783    1455177
# 142784    1455177
# 142786    1311639
# 142788    1311639
# 142789    1438894
# 142791    1438894
# 142793    1387134
# 142794    1387134
# 142802    1430583
# 142803    1430583
# 142804    1408950
# 142806    1408950
# 142807    1561933
# 142810    1545423
# 142812    1397803
# 142814    1397803
# 142815    1558525
# 142818    1535068
# 142819    1558523
# 142820    1557680
# 142828    1557533
# 142833    1576569
# 142834    1575451
# 142851    1535074
# 142856    2185389
# 142863    1543989
# 142866    1561930
# 142881    1575452
# 142887    1576570
# 142888    1575430
# 142889    1575431
# 142892    1504446
# 142894    1550476
# 142898    1558010
# 142900    2187041
# 142944    2206025
# 142959    2185380
# 142969    1557676
# 142973    1557517
# 142978    1557676
# 142991    1557687
# 142993    1557537
# 143026    1552544
# 143032    1552545
# 143033    1538114
# 143034    2057458
# 143037    1543985
# 143038    1552545
# 143039    2057458
# 143040    1557675
# 143041    1557536
# 143042    2057458
# 143045    1552547
# 143050    2057458
# 143055    1564385
# 143061    1552547
# 143062    1552548
# 143063    2187039
# 143074    1557515
# 143075    1552546
# 143079    1557675
# 143090    1568368
# 143094    1561926
# 143095    1552538
# 143120     984049
# 143124    1545458
# 143125    2206017
# 143129    1557513
# 143134    1552549
# 143139    1564394
# 143151    1550115
# 143152    1552336
# 143175    2206030
# 143179    1568368
# 143187    1550740
# 143189    1491673
# 143191    1550849
# 143193    1547712
# 143194    2182924
# 143195    1547703
# 143196    1547704
# 143202    1575432
# 143225    2206015
# 143243    1561963
# 143247    1543886
# 143248    1543883
# 143251    1543884
# 143252    1543885
# 143257    1564858
# 143263    1542534
# 143265    1547160
# 143266    1545255
# 143269    1547158
# 143270    1542533
# 143273    1542532
# 143277    1545254
# 143278    1545252
# 143280    1158730
# 143281    1549891
# 143282    1545247
# 143285    1547157
# 143290    1538114
# 143310    1387132
# 143311    1387132
# 143313    1277565
# 143314    1277565
# 143315    1314947
# 143316    1314947
# 143317    1375542
# 143318    2187558
# 143319    1375542
# 143320    1375556
# 143322    1375556
# 143324    1311630
# 143325    1311630
# 143326    1297788
# 143327    1297788
# 143329    1311642
# 143330    1311642
# 143331    1297797
# 143332    1297797
# 143334    1280502
# 143335    1280502
# 143336    1285818
# 143337    2173338
# 143338    1285818
# 143339    1294069
# 143340    1294069
# 143342    1277564
# 143344    1277564
# 143345    1561928
# 143346    1279701
# 143347    1279701
# 143349    1550476
# 143353    1560358
# 143358    1579279
# 143367    1575413
# 143370    1564811
# 143373    1564822
# 143375    1249396
# 143376    1249396
# 143378    1241281
# 143380    1241281
# 143381     623192
# 143382    1561918
# 143383    1241291
# 143384    1241291
# 143386    1564854
# 143387    1249142
# 143388    1249142
# 143390    1247453
# 143391    1247453
# 143392    1247235
# 143394    1247235
# 143395    1249430
# 143397    1249430
# 143399    1564845
# 143400    1267593
# 143401    1267593
# 143403    1249409
# 143404    1249409
# 143405    1265776
# 143406    1265776
# 143407    2180228
# 143408    1564847
# 143409    1270977
# 143410    2180235
# 143411    1270977
# 143412    1270986
# 143413    1270986
# 143414    1265774
# 143415    1265774
# 143420    1564846
# 143425    1564851
# 143428    1564848
# 143432    1564860
# 143454    1564808
# 143471    1550848
# 143475    1575402
# 143485    2183026
# 143489    1560358
# 143501    1564822
# 143502    1564399
# 143506    2186738
# 143509    2127754
# 143510    1552459
# 143513    2182656
# 143521    2183026
# 143524    1673034
# 143533    1564810
# 143538    1547675
# 143601    1561918
# 143602    1564809
# 143627    1545522
# 143628    1568371
# 143629    1564859
# 143641    1578986
# 143664    1564849
# 143670    1558013
# 143693    1571830
# 143694    1550477
# 143707    1578170
# 143725    1588117
# 143727    1575429
# 143729     623192
# 143756    2178729
# 143758    2080326
# 143780    2183112
# 143784    2183115
# 143805    1564834
# 143806    1455178
# 143815    2183111
# 143817    2183111
# 143820    1575414
# 143841    1559358
# 143842    1561976
# 143869    1552339
# 143906    1550477
# 143913    1575412
# 143921    1561976
# 143931    1547397
# 143944    1547676
# 143948    1575753
# 143963    1547396
# 143967    1395337
# 143982    1579269
# 144061    1535066
# Name: odt, dtype: int64

# %%
df_zona_pacifico.loc[:, "item_288"] = df_zona_pacifico["odt"].map(
    df_odt_number.set_index("odt")["value"]
)

# %%
df_zona_pacifico.head(5)
# Out:
#         odt     value item_288
# 7   1561972  PACIFICO  1234558
# 11  1813259  PACIFICO  1042646
# 15  1458468  PACIFICO  8555454
# 17  1458468  PACIFICO  8555454
# 18  1462340  PACIFICO  1018897

# %%
df_zona_pacifico["item_288"].isna().sum()
# Out:
# 4260

# %%
## Vacíos de los datasets por año

# # Contar los registros donde item_288 es igual a 0
conteo_ceros = (nuevo_dataset_2023["item_288"] == 0).sum()
print(f"Año 2023 - Número de registros con Código Interno vacío: {conteo_ceros}")
# Out:
# Año 2023 - Número de registros con Código Interno vacío: 4260

# %%
# Modificar el DataFrame original
df_zona_pacifico = df_zona_pacifico.dropna(subset=["item_288"])

# %%
## Eliminar vacíos por año

# # Eliminar los registros donde item_288 es igual a 0
nuevo_dataset_2023_filtrado = nuevo_dataset_2023[nuevo_dataset_2023["item_288"] != 0]

# Guardar el DataFrame filtrado en un archivo CSV
ruta_guardado = data_interim_dir("nuevo_dataset_2023_f.csv")

nuevo_dataset_2023_filtrado.to_csv(ruta_guardado, index=False)
print(f"Año 2023 - Registros eliminados y guardados en: {ruta_guardado}")
# Out:
# Año 2023 - Registros eliminados y guardados en: /Users/frandak2/Documents/repos/cedenar_anomalies/data/interim/nuevo_dataset_2023_f.csv

# %%
nuevo_dataset_2023_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19587 entries, 0 to 23846
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   odt       19587 non-null  int64
#  1   item_288  19587 non-null  int64
# dtypes: int64(2)
# memory usage: 459.1 KB

# %%
df_zona_pacifico.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19587 entries, 7 to 144061
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   odt       19587 non-null  int64
#  1   value     19587 non-null  object
#  2   item_288  19587 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 612.1+ KB

# %% [markdown]
# ### Usuarios Pacifico

# %%
ruta_archivo = data_raw_dir("cedenar_data.xlsx")
usu_pacifico = pd.read_excel(ruta_archivo)
usu_pacifico = usu_pacifico[usu_pacifico.ZONA == "PACIFICO"]

# %%
usu_pacifico.head(2)
# Out:
#      PRODUCT_ID  PRODUCTO  CONTRATO  CLIENTE  \
# 146      597102    597102    597102   100706
# 154     1184921   1184921   1184921   100802
#
#                         NOMBRE_CLIENTE   APELLIDO_CLIENTE      ZONA SECCIONAL  \
# 146  MARCIAL VICTORIANO_ LOPEZ NARVAEZ                NaN  PACIFICO  PACIFICO
# 154                    ZAIDA JACKELINE  VALVERDE QUIÑONES  PACIFICO  PACIFICO
#
#             DIRECCION_PRODUCTO MUNICIPIO_PRODUCTO  \
# 146  EL ESFURZO I CS 347 DIV 1             TUMACO
# 154     CS 53 A PRADOMAR DIV 1             TUMACO
#
#                                  VEREDA_CENTRO_POBLADO BARRIO_PRODUCTO  \
# 146  SAN ANDRES DE TUMACO  DISTRITO ESPECIAL  INDUS...     EL ESFUERZO
# 154  SAN ANDRES DE TUMACO  DISTRITO ESPECIAL  INDUS...        PRADOMAR
#
#     SECTOR_OPERATIVO_PRODUCTO  COD_CICLO_CONSUMO  \
# 146        114-TUMACO  URBANO                  4
# 154        114-TUMACO  URBANO                 54
#
#                       CICLO_CONSUMO  COD_CICLO_FACTURACION  \
# 146  0Y-TARIFA PARA CLAUSURA PACIFI                      4
# 154   0G-MEDIDA CENTRALIZADA TUMACO                     54
#
#                   CICLO_FACTURACION    RUTA  \
# 146  0Y-TARIFA PARA CLAUSURA PACIFI     5.0
# 154   0G-MEDIDA CENTRALIZADA TUMACO  4040.0
#
#                                               DES_RUTA  ORDEN_PREDIO    AREA  \
# 146                           2182-RUTA 2182 DE TUMACO        6058.0  Urbano
# 154  7510 - TUMACO VIADUCTO CONVENCIONAL MORRITO TR...       35560.0  Urbano
#
#     FECHA_INSTALACION_PRODUCTO       ESTADO_DE_CORTE ESTADO_PRODUCTO  \
# 146                 2000-10-10  92-Retiro definitivo      3-Retirado
# 154                 2016-02-29            1-Conexión        1-Activo
#
#     FECHA_RETIRO_PRODUCTO SERVICIO_PROVISIONAL PRODUCTO_ACTIVO      CATEGORIA  \
# 146            2020-07-06                    N               N  1-RESIDENCIAL
# 154            4732-12-31                    N               Y  1-RESIDENCIAL
#
#     SUB_CATEGORIA  ZONA_TARIFARIA                  PLAN_COMERCIAL  \
# 146   1-ESTRATO 1  -1-POR DEFECTO        16-RESIDENCIAL - DIRECTO
# 154   1-ESTRATO 1  -1-POR DEFECTO  31-PLAN RESIDENCIAL TELEMEDIDO
#
#                   METOD_VARCON  TRAFO_OPEN FECHA_INGRESO_A_SISTEMA  \
# 146    5013-PRODUCTOS DIRECTOS     TM30006              2000-10-10
# 154  5004-CLIENTES TELEMEDIDOS  60TA030352              2016-02-29
#
#     FECHA_DE_CONEXION  CARTERA_EN_MORA  CARTERA_TOTAL  CARGA_INSTALADA  \
# 146        2000-10-10              NaN            NaN              1.0
# 154        2016-02-29              0.0        47090.0              1.8
#
#     MODO_ADQUISICION    MEDIDOR  COMPONENTE  CODIGO_MEDIDOR FECHA_INSTALACION  \
# 146              NaN        NaN         NaN             NaN               NaN
# 154     C - comodato  MEC-54186   1605850.0        301790.0        2016-02-29
#
#              ESTADO_MEDIDOR  COMPONENT_TYPE_ID    CLASE_SERVICIO TIPO_MEDIDOR  \
# 146                     NaN                NaN               NaN          NaN
# 154  21-Pendiente de Retiro               18.0  3257-MEDIDOR AMI          NaN
#
#     GAMA TIPO_ITEM  FASES TRAFO_SPARD   KVA CIRCUITO  NIVEL  LATI_USU  \
# 146  NaN       NaN    NaN         NaN   NaN      NaN    NaN       NaN
# 154  NaN       NaN    NaN  60TA030352  45.0   60TM03    1.0  1.819331
#
#       LONG_USU  LATI_TRAFO  LONG_TRAFO
# 146        NaN         NaN         NaN
# 154 -78.749592    1.819363  -78.749388

# %%
# Crear una función para verificar la existencia de los usuarios en Base de datos pacifico y devolver "si" o "no"
def verificar_existencia(valor):
    if valor in usu_pacifico["PRODUCTO"].values:
        return "si"
    else:
        return "no"

# %%
nuevo_dataset_copia = nuevo_dataset_2023_filtrado.copy()

# Aplicar la función a la columna item_288 y crear la columna existencia
nuevo_dataset_copia["existencia"] = nuevo_dataset_copia["item_288"].apply(
    verificar_existencia
)

nuevo_dataset_copia.to_csv(
    data_interim_dir("nuevo_dataset_comprob_2023_filtrado.csv"), index=False
)

# %%
nuevo_dataset_copia["existencia"].value_counts()
# Out:
# existencia
# si    19584
# no        3
# Name: count, dtype: int64

# %% [markdown]
# ### Eliminar ODT sin coincidencia en Productos pacifico

# %%
def eliminar_y_exportar(df_original, nombre_archivo_salida):
    """
    Elimina los registros donde 'existencia' es 'no', elimina la columna 'existencia' y guarda el DataFrame en un archivo CSV.

    Parámetros:
    - df_original (DataFrame): El DataFrame original con la columna 'existencia'.
    - nombre_archivo_salida (str): El nombre del archivo CSV de salida.
    """

    # Crear una copia del DataFrame para no modificar el original
    df_copia = df_original.copy()

    # Eliminar los registros donde 'existencia' es 'no'
    df_filtrado = df_copia[df_copia["existencia"] != "no"]

    # Eliminar la columna 'existencia'
    df_filtrado = df_filtrado.drop(columns=["existencia"])

    # Guardar el DataFrame filtrado en un archivo CSV
    df_filtrado.to_csv(data_interim_dir(nombre_archivo_salida), index=False)

    print(
        f"Registros eliminados y guardados en: {data_interim_dir(nombre_archivo_salida)}"
    )

# %%
ruta_archivo = data_interim_dir("nuevo_dataset_comprob_2023_filtrado.csv")
df_2023_f_c = pd.read_csv(ruta_archivo)

# %%
eliminar_y_exportar(df_2023_f_c, "df_odt_prod_2023.csv")
# Out:
# Registros eliminados y guardados en: /Users/frandak2/Documents/repos/cedenar_anomalies/data/interim/df_odt_prod_2023.csv

# %%
# Convert the object column to int64
df_zona_pacifico["item_288"] = df_zona_pacifico["item_288"].astype(int)

# Then do the merge
df_odt_pacifico_prod = pd.merge(
    df_zona_pacifico[["odt", "item_288"]],
    usu_pacifico[["PRODUCTO", "AREA", "PLAN_COMERCIAL", "NIVEL", "LATI_USU", "LONG_USU"]],
    left_on="item_288",
    right_on="PRODUCTO",
    how="inner",
)
# Remove the duplicate PRODUCTO column
df_odt_pacifico_prod = df_odt_pacifico_prod.drop(columns=["PRODUCTO"])
df_odt_pacifico_prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19584 entries, 0 to 19583
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   odt             19584 non-null  int64
#  1   item_288        19584 non-null  int64
#  2   AREA            19584 non-null  object
#  3   PLAN_COMERCIAL  19584 non-null  object
#  4   NIVEL           19584 non-null  float64
#  5   LATI_USU        19584 non-null  float64
#  6   LONG_USU        19584 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 1.0+ MB

# %% [markdown]
# ### Agregar datos de usuario

# %%
ruta_archivo = data_interim_dir("df_odt_prod_2023.csv")
df_odt_prod_2023 = pd.read_csv(ruta_archivo)

# %%
df_odt_prod_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19584 entries, 0 to 19583
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   odt       19584 non-null  int64
#  1   item_288  19584 non-null  int64
# dtypes: int64(2)
# memory usage: 306.1 KB

# %%
# Crear un diccionario de mapeo para los campos a agregar
mapeo_productos = usu_pacifico.set_index("PRODUCTO")[
    ["AREA", "PLAN_COMERCIAL", "NIVEL", "LATI_USU", "LONG_USU"]
].to_dict("index")


# Función para obtener los valores correspondientes
def obtener_datos_usuario(producto):
    if producto in mapeo_productos:
        return pd.Series(mapeo_productos[producto])
    else:
        return pd.Series(
            [None] * 5, index=["AREA", "PLAN_COMERCIAL", "NIVEL", "LATI_USU", "LONG_USU"]
        )

# %%
# Aplicar la función a la columna item_288 y agregar las nuevas columnas
df_odt_prod_2023[["AREA", "PLAN_COMERCIAL", "NIVEL", "LATI_USU", "LONG_USU"]] = (
    df_odt_prod_2023["item_288"].apply(obtener_datos_usuario)
)

# Mostrar las primeras filas del DataFrame con las nuevas columnas
print(df_odt_prod_2023.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19584 entries, 0 to 19583
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   odt             19584 non-null  int64
#  1   item_288        19584 non-null  int64
#  2   AREA            19584 non-null  object
#  3   PLAN_COMERCIAL  19584 non-null  object
#  4   NIVEL           19584 non-null  float64
#  5   LATI_USU        19584 non-null  float64
#  6   LONG_USU        19584 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 1.0+ MB
# None

# %%
df_odt_prod_2023.head(2)
# Out:
#        odt  item_288    AREA                  PLAN_COMERCIAL  NIVEL  LATI_USU  \
# 0  1561972   1234558  Urbano  31-PLAN RESIDENCIAL TELEMEDIDO    1.0  1.779928
# 1  1813259   1042646  Urbano  31-PLAN RESIDENCIAL TELEMEDIDO    1.0  1.819217
#
#     LONG_USU
# 0 -78.787850
# 1 -78.735098

# %%
df_odt_pacifico_prod.head(2)
# Out:
#        odt  item_288    AREA                  PLAN_COMERCIAL  NIVEL  LATI_USU  \
# 0  1561972   1234558  Urbano  31-PLAN RESIDENCIAL TELEMEDIDO    1.0  1.779928
# 1  1813259   1042646  Urbano  31-PLAN RESIDENCIAL TELEMEDIDO    1.0  1.819217
#
#     LONG_USU
# 0 -78.787850
# 1 -78.735098

# %%
df_odt_prod_2023.to_csv(data_interim_dir("df_odt_prod_2023_f.csv"), index=False)

# %% [markdown]
# ### Traducir orden con uid

# %%
ruta_archivo = data_raw_dir("conversion uid orden.xlsx")
odt_a_uid = pd.read_excel(ruta_archivo)
odt_a_uid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 242988 entries, 0 to 242987
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   uid     242988 non-null  int64
#  1   orden   242988 non-null  int64
# dtypes: int64(2)
# memory usage: 3.7 MB

# %%
odt_a_uid.head(2)
# Out:
#        uid     orden
# 0  1270785  25503591
# 1  2041056  28157132

# %%
# Crear un diccionario de mapeo de 'orden' a 'uid'
mapeo_orden_uid = odt_a_uid.set_index("uid")["orden"].to_dict()


# Función para obtener el uid correspondiente
def obtener_uid(orden):
    if orden in mapeo_orden_uid:
        return mapeo_orden_uid[orden]
    else:
        return None

# %% [markdown]
# #### 2023

# %%
# ruta_archivo = 'J:\\JESSICA\\Jessica\\Rafael\\igrid\\cedenar\\python_zentr\\df_odt_prod_2023_f.csv'  # Reemplaza con tu ruta
ruta_archivo = data_interim_dir("df_odt_prod_2023_f.csv")
df_odt_prod_2023 = pd.read_csv(ruta_archivo)

# %%
df_odt_prod_2023["orden"] = df_odt_prod_2023["odt"].apply(obtener_uid)

# %%
df_odt_prod_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19584 entries, 0 to 19583
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   odt             19584 non-null  int64
#  1   item_288        19584 non-null  int64
#  2   AREA            19584 non-null  object
#  3   PLAN_COMERCIAL  19584 non-null  object
#  4   NIVEL           19584 non-null  float64
#  5   LATI_USU        19584 non-null  float64
#  6   LONG_USU        19584 non-null  float64
#  7   orden           19584 non-null  int64
# dtypes: float64(3), int64(3), object(2)
# memory usage: 1.2+ MB

# %%
df_odt_prod_2023.head(2)
# Out:
#        odt  item_288    AREA                  PLAN_COMERCIAL  NIVEL  LATI_USU  \
# 0  1561972   1234558  Urbano  31-PLAN RESIDENCIAL TELEMEDIDO    1.0  1.779928
# 1  1813259   1042646  Urbano  31-PLAN RESIDENCIAL TELEMEDIDO    1.0  1.819217
#
#     LONG_USU     orden
# 0 -78.787850  26200906
# 1 -78.735098  27383608

# %%
df_odt_pacifico_prod_uid = pd.merge(
    df_odt_pacifico_prod,  # Only include needed columns
    odt_a_uid,
    left_on="odt",
    right_on="uid",
    how="inner",
)
# Remove the duplicate PRODUCTO column
df_odt_pacifico_prod_uid = df_odt_pacifico_prod_uid.drop(columns=["uid"])
df_odt_pacifico_prod_uid.head(2)
# Out:
#        odt  item_288    AREA                  PLAN_COMERCIAL  NIVEL  LATI_USU  \
# 0  1561972   1234558  Urbano  31-PLAN RESIDENCIAL TELEMEDIDO    1.0  1.779928
# 1  1813259   1042646  Urbano  31-PLAN RESIDENCIAL TELEMEDIDO    1.0  1.819217
#
#     LONG_USU     orden
# 0 -78.787850  26200906
# 1 -78.735098  27383608

# %%
df_odt_prod_2023.to_csv(data_interim_dir("df_odt_prod_2023_uid.csv"), index=False)

# %% [markdown]
# ### Unir a "anomalias 2023"

# %%
# ruta_archivo = 'J:\\JESSICA\\Jessica\\Rafael\\igrid\\cedenar\\python_zentr\\zentry\\anomalias 2023.xlsx'
ruta_archivo = data_raw_dir("anomalias 2022 23 y 24.xlsx")
anom_a_2023 = pd.read_excel(ruta_archivo)

# %%
anom_a_2023.sample(10)
# Out:
#       Zona      Contrato     Orden  Usuario     Estado  \
# 1862    PA  DIC 181.2022  17090799   378288   Aprobada
# 33173   NO  EMP 327.2024  36479863  1240883  Rechazada
# 32513   SU  SIN 337.2024  36035602  1181869   Aprobada
# 23195   NO  UNI 210.2023  29353524  1226899  Pendiente
# 11007   PA  MEC 495.2022  21357036   579944   Aprobada
# 23547   PA  DIC 209.2023  29585916  1022340   Aprobada
# 12815   PA  GLO 264.2022  22156541  1136696  Rechazada
# 21136   PA  DIC 209.2023  27888068  1077898   Aprobada
# 17079   CE  ING 233.2023  25143547   500099  Rechazada
# 9846    OC  R Y 177.2022  20918952   234560  Pendiente
#
#                     Ejecucion                       Revision  \
# 1862   2022-02-07 10:35:21-05  2022-02-10 04:10:23.920733-05
# 33173  2024-10-22 20:19:26-05  2024-11-05 18:04:05.095203-05
# 32513  2024-10-23 12:04:11-05  2024-10-24 02:32:37.814261-05
# 23195  2023-11-24 08:15:09-05                            NaN
# 11007  2022-09-14 17:21:48-05  2022-09-20 10:29:00.537528-05
# 23547  2023-11-17 16:49:25-05   2023-11-18 01:56:45.78407-05
# 12815  2022-10-27 16:39:02-05  2022-11-08 11:19:13.140512-05
# 21136  2023-08-22 15:52:13-05  2023-08-28 11:33:09.634618-05
# 17079  2023-04-03 11:37:49-05  2023-05-08 17:52:27.795609-05
# 9846   2022-08-19 11:34:45-05                            NaN
#
#                            Codigo  \
# 1862         82 / 38 / 30004 / 82
# 33173                          38
# 32513            38 / 1 / 82 / 38
# 23195                         NaN
# 11007       3 / 82 / H1 / 39 / 38
# 23547  39 / 1 / 38 / 39 / 82 / 82
# 12815                          38
# 21136   82 / 38 / 18 / 30001 / 82
# 17079                   BPQ / N/A
# 9846                 82 / 38 / 38
#
#                                                 Anomalia  N. Unidad  \
# 1862   Se Corrige Anomalía / Inspección Técnica Confo...          0
# 33173                        Inspección Técnica Conforme          0
# 32513  Acometida Intervenid / ACOMETIDA O DERIVACIÓN ...          0
# 23195                                medidor no conforme          0
# 11007  RECONEXIÓN NO AUTORIZADA DEL SERVICIO POR FUER...          0
# 23547  Medidor desconectado / ACOMETIDA O DERIVACIÓN ...          0
# 12815                        Inspección Técnica Conforme          0
# 21136  Se Corrige Anomalía / Inspección Técnica Confo...          0
# 17079   Bornera Perforada/Quemada  / medidor no conforme          0
# 9846   Se Corrige Anomalía / Inspección Técnica Confo...          0
#
#                  Unidad  N. Causa                 Causa   U. Genera  \
# 1862   CONTROL PERDIDAS         0  CAUSA NO DETERMINADA   GSANDOVAL
# 33173   GES. ENERGETICA         0  CAUSA NO DETERMINADA    HCORDOBA
# 32513   GES. ENERGETICA         0  CAUSA NO DETERMINADA     DREVELO
# 23195   GES. ENERGETICA         0  CAUSA NO DETERMINADA   WARCOS123
# 11007   GES. ENERGETICA         0  CAUSA NO DETERMINADA   JSAAVEDRA
# 23547  CONTROL PERDIDAS         0  CAUSA NO DETERMINADA   GSANDOVAL
# 12815   GES. ENERGETICA         0  CAUSA NO DETERMINADA   GSANDOVAL
# 21136  CONTROL PERDIDAS         0  CAUSA NO DETERMINADA   GSANDOVAL
# 17079       FACTURACION         0  CAUSA NO DETERMINADA  GZARCOS123
# 9846   CONTROL PERDIDAS         0  CAUSA NO DETERMINADA      LMMORA
#
#                                 Descripcion                            Motivo  \
# 1862         Anomalia verificada y aprobada                   Otras Anomalias
# 33173  Anomalia verificada con acta digital     No Existe Anomalía En El Acta
# 32513        Anomalia verificada y aprobada  Creacion Sello Tapa Principal #4
# 23195                      Posible anomalia                        Disponible
# 11007        Anomalia verificada y aprobada                Movimiento Bodegas
# 23547        Anomalia verificada y aprobada  Creacion Sello Tapa Principal #4
# 12815  Anomalia verificada con acta digital                   No Procede Pare
# 21136        Anomalia verificada y aprobada               Luminaria Encendida
# 17079  Anomalia verificada con acta digital                   No Procede Pare
# 9846                       Posible anomalia                               NaN
#
#       Cuadrilla  kWh Rec  Factor
# 1862    ZTY1151   1673.0     NaN
# 33173   ZTY1691      0.0     NaN
# 32513   ZTY1722    624.0     NaN
# 23195   ZTY1372      0.0     NaN
# 11007   ZTY1314      0.0     NaN
# 23547   ZTY1407   2269.0     NaN
# 12815   ZTY1223      NaN     NaN
# 21136   ZTY1407   2082.0     NaN
# 17079   ZTY1346      0.0     NaN
# 9846    ZTY1131   1680.0     NaN

# %%
# Si la columna es de tipo datetime
if pd.api.types.is_datetime64_any_dtype(anom_a_2023["Ejecucion"]):
    # Extraer el año directamente
    anom_a_2023["año"] = anom_a_2023["Ejecucion"].dt.year
else:
    # Si es un string, primero intentamos convertirla a datetime
    try:
        # Convertir a datetime y extraer el año
        anom_a_2023["año"] = pd.to_datetime(anom_a_2023["Ejecucion"]).dt.year
    except:
        # Si no se puede convertir a datetime, extraer usando regex o string slicing
        # Método con regex (suponiendo que el año está en formato YYYY en alguna parte del string)
        anom_a_2023["año"] = (
            anom_a_2023["Ejecucion"].str.extract(r"(\d{4})", expand=False).astype(float)
        )

anom_a_2023.año.value_counts()
# Out:
# año
# 2022    14480
# 2024     9845
# 2023     9490
# 2021      864
# 2020        4
# Name: count, dtype: int64

# %%
anom_a_2023 = anom_a_2023[anom_a_2023.año == 2023]

# %%
# Identificar registros duplicados en 'Orden' y donde 'Codigo' es 'N/A'
anom_a_2023["Codigo"] = anom_a_2023["Codigo"].astype(str)
anom_a_2023["Revision"] = anom_a_2023["Revision"].astype(str)
duplicados_con_na = anom_a_2023[
    (anom_a_2023.duplicated(subset="Orden", keep=False))
    & (anom_a_2023["Revision"] == "nan")
]

# Obtener los índices de los registros a eliminar
indices_a_eliminar = duplicados_con_na.index

# Eliminar los registros
anom_a_2023_filtrado = anom_a_2023.drop(indices_a_eliminar)

# Guardar el nuevo dataframe en un archivo csv
anom_a_2023_filtrado.to_csv("anom_a_2023_filtrado.csv", index=False)
anom_a_2023_filtrado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9061 entries, 7577 to 24895
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Zona         9061 non-null   object
#  1   Contrato     9061 non-null   object
#  2   Orden        9061 non-null   int64
#  3   Usuario      9061 non-null   int64
#  4   Estado       9061 non-null   object
#  5   Ejecucion    9061 non-null   object
#  6   Revision     9061 non-null   object
#  7   Codigo       9061 non-null   object
#  8   Anomalia     9061 non-null   object
#  9   N. Unidad    9061 non-null   int64
#  10  Unidad       9061 non-null   object
#  11  N. Causa     9061 non-null   int64
#  12  Causa        9061 non-null   object
#  13  U. Genera    9061 non-null   object
#  14  Descripcion  9061 non-null   object
#  15  Motivo       8907 non-null   object
#  16  Cuadrilla    9061 non-null   object
#  17  kWh Rec      6576 non-null   float64
#  18  Factor       25 non-null     float64
#  19  año          9061 non-null   int32
# dtypes: float64(2), int32(1), int64(4), object(13)
# memory usage: 1.4+ MB

# %%
# Crear un diccionario de mapeo para los campos a agregar
mapeo_productos = anom_a_2023_filtrado.set_index("Orden")[["Descripcion"]].to_dict(
    "index"
)


# Función para obtener los valores correspondientes
def obtener_datos_usuario(producto):
    if producto in mapeo_productos:
        return pd.Series(mapeo_productos[producto])
    else:
        return pd.Series([None] * 1, index=["Descripcion"])

# %% [markdown]
# ### 2023

# %%
df_odt_prod_2023[["Descripcion"]] = df_odt_prod_2023["orden"].apply(obtener_datos_usuario)

# Mostrar las primeras filas del DataFrame con las nuevas columnas
print(df_odt_prod_2023.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19584 entries, 0 to 19583
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   odt             19584 non-null  int64
#  1   item_288        19584 non-null  int64
#  2   AREA            19584 non-null  object
#  3   PLAN_COMERCIAL  19584 non-null  object
#  4   NIVEL           19584 non-null  float64
#  5   LATI_USU        19584 non-null  float64
#  6   LONG_USU        19584 non-null  float64
#  7   orden           19584 non-null  int64
#  8   Descripcion     3344 non-null   object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 1.3+ MB
# None

# %%
ruta_archivo = data_interim_dir("df_odt_prod_2023_dscr.csv")
df_odt_prod_2023.to_csv(ruta_archivo, index=False)

# %%
df_odt_prod_2023.head(2)
# Out:
#        odt  item_288    AREA                  PLAN_COMERCIAL  NIVEL  LATI_USU  \
# 0  1561972   1234558  Urbano  31-PLAN RESIDENCIAL TELEMEDIDO    1.0  1.779928
# 1  1813259   1042646  Urbano  31-PLAN RESIDENCIAL TELEMEDIDO    1.0  1.819217
#
#     LONG_USU     orden Descripcion
# 0 -78.787850  26200906        None
# 1 -78.735098  27383608        None

# %%
df_odt_pacifico_prod_uid_desc = pd.merge(
    df_odt_pacifico_prod_uid,  # Only include needed columns
    anom_a_2023_filtrado[["Orden", "Descripcion"]],
    left_on="orden",
    right_on="Orden",
    how="left",
)
# Remove the duplicate PRODUCTO column
df_odt_pacifico_prod_uid_desc = df_odt_pacifico_prod_uid_desc.drop(columns=["Orden"])
df_odt_pacifico_prod_uid_desc.head(2)
# Out:
#        odt  item_288    AREA                  PLAN_COMERCIAL  NIVEL  LATI_USU  \
# 0  1561972   1234558  Urbano  31-PLAN RESIDENCIAL TELEMEDIDO    1.0  1.779928
# 1  1813259   1042646  Urbano  31-PLAN RESIDENCIAL TELEMEDIDO    1.0  1.819217
#
#     LONG_USU     orden Descripcion
# 0 -78.787850  26200906         NaN
# 1 -78.735098  27383608         NaN

# %%
df_odt_pacifico_prod_uid_desc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19584 entries, 0 to 19583
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   odt             19584 non-null  int64
#  1   item_288        19584 non-null  int64
#  2   AREA            19584 non-null  object
#  3   PLAN_COMERCIAL  19584 non-null  object
#  4   NIVEL           19584 non-null  float64
#  5   LATI_USU        19584 non-null  float64
#  6   LONG_USU        19584 non-null  float64
#  7   orden           19584 non-null  int64
#  8   Descripcion     3344 non-null   object
# dtypes: float64(3), int64(3), object(3)
# memory usage: 1.3+ MB

# %% [markdown]
# ### Unión items por odt

# %%
def unir_niveles(anio, niveles, nuevo_dataset):
    """
    Función para agregar datos de múltiples datasets a un dataset base usando la columna 'odt'.

    Parámetros:
    - anio (int): Año de los datasets.
    - niveles (list): Lista de IDs de variables a procesar.
    - nuevo_dataset (DataFrame): Dataset base al que se le agregarán las columnas.

    Retorna:
    - DataFrame con las columnas agregadas.
    """
    nuevo_dataset = nuevo_dataset.copy()

    # Conservar las columnas 'existencia' y 'item_288' al inicio
    columnas_conservadas = []
    if "item_288" in nuevo_dataset.columns:
        columnas_conservadas.append("item_288")
    if "PLAN_COMERCIAL" in nuevo_dataset.columns:
        columnas_conservadas.append("PLAN_COMERCIAL")
    if "NIVEL" in nuevo_dataset.columns:
        columnas_conservadas.append("NIVEL")
    if "LATI_USU" in nuevo_dataset.columns:
        columnas_conservadas.append("LATI_USU")
    if "LONG_USU" in nuevo_dataset.columns:
        columnas_conservadas.append("LONG_USU")
    if "AREA" in nuevo_dataset.columns:
        columnas_conservadas.append("AREA")
    if "Descripcion" in nuevo_dataset.columns:
        columnas_conservadas.append("Descripcion")

    for nivel in niveles:
        df_actual = globals().get(f"evento{anio}_{nivel}")

        if df_actual is not None:
            if "odt" in df_actual.columns and "value" in df_actual.columns:
                df_actual = df_actual[["odt", "value"]].drop_duplicates(subset="odt")
                nuevo_dataset[f"item_{nivel}"] = nuevo_dataset["odt"].map(
                    df_actual.set_index("odt")["value"]
                )

                print(f"✔️ Procesado: evento{anio}_{nivel}")
            else:
                print(f"⚠️ Columnas faltantes en: evento{anio}_{nivel}")
        else:
            print(f"⚠️ No encontrado: evento{anio}_{nivel}")

    # Reorganizar las columnas para que 'existencia' y 'item_288' estén al inicio
    columnas_restantes = [
        col for col in nuevo_dataset.columns if col not in columnas_conservadas
    ]
    nuevo_dataset = nuevo_dataset[columnas_conservadas + columnas_restantes]

    # Guardar el dataset consolidado
    output_path = data_processed_dir(f"dataset_decantado_{anio}.csv")
    nuevo_dataset.to_csv(output_path, index=False)
    print(f"✅ Proceso completado. Dataset guardado en {output_path}.")

    return nuevo_dataset

# %% [markdown]
# ### 2022

# %% [markdown]
# ### 2023

# %%
# Lista de ids de variables
niveles = [
    1442,
    8,
    237,
    23,
    24,
    33,
    598,
    601,
    43,
    99,
    35,
    111,
    599,
    108,
    603,
    190,
    192,
    588,
    248,
    591,
    602,
    41,
    211,
    74,
    1889,
    597,
    600,
    37,
    1407,
    1410,
    68,
    1328,
    1334,
    594,
    67,
    1408,
    1352,
    1405,
    1283,
    1343,
    1346,
    1292,
    1298,
    69,
    1331,
    202,
    1349,
]

dataset_decan_2023 = unir_niveles(2023, niveles, df_odt_prod_2023)
dataset_decan_2023.head(2)
# Out:
# ✔️ Procesado: evento2023_1442
# ✔️ Procesado: evento2023_8
# ✔️ Procesado: evento2023_237
# ✔️ Procesado: evento2023_23
# ✔️ Procesado: evento2023_24
# ✔️ Procesado: evento2023_33
# ✔️ Procesado: evento2023_598
# ✔️ Procesado: evento2023_601
# ✔️ Procesado: evento2023_43
# ✔️ Procesado: evento2023_99
# ✔️ Procesado: evento2023_35
# ✔️ Procesado: evento2023_111
# ✔️ Procesado: evento2023_599
# ✔️ Procesado: evento2023_108
# ✔️ Procesado: evento2023_603
# ✔️ Procesado: evento2023_190
# ✔️ Procesado: evento2023_192
# ✔️ Procesado: evento2023_588
# ✔️ Procesado: evento2023_248
# ✔️ Procesado: evento2023_591
# ✔️ Procesado: evento2023_602
# ✔️ Procesado: evento2023_41
# ✔️ Procesado: evento2023_211
# ✔️ Procesado: evento2023_74
# ✔️ Procesado: evento2023_1889
# ✔️ Procesado: evento2023_597
# ✔️ Procesado: evento2023_600
# ✔️ Procesado: evento2023_37
# ✔️ Procesado: evento2023_1407
# ✔️ Procesado: evento2023_1410
# ✔️ Procesado: evento2023_68
# ✔️ Procesado: evento2023_1328
# ✔️ Procesado: evento2023_1334
# ✔️ Procesado: evento2023_594
# ✔️ Procesado: evento2023_67
# ✔️ Procesado: evento2023_1408
# ✔️ Procesado: evento2023_1352
# ✔️ Procesado: evento2023_1405
# ✔️ Procesado: evento2023_1283
# ✔️ Procesado: evento2023_1343
# ✔️ Procesado: evento2023_1346
# ✔️ Procesado: evento2023_1292
# ✔️ Procesado: evento2023_1298
# ✔️ Procesado: evento2023_69
# ✔️ Procesado: evento2023_1331
# ✔️ Procesado: evento2023_202
# ✔️ Procesado: evento2023_1349
# ✅ Proceso completado. Dataset guardado en /Users/frandak2/Documents/repos/cedenar_anomalies/data/processed/dataset_decantado_2023.csv.
#    item_288                  PLAN_COMERCIAL  NIVEL  LATI_USU   LONG_USU  \
# 0   1234558  31-PLAN RESIDENCIAL TELEMEDIDO    1.0  1.779928 -78.787850
# 1   1042646  31-PLAN RESIDENCIAL TELEMEDIDO    1.0  1.819217 -78.735098
#
#      AREA Descripcion      odt     orden  item_1442     item_8 item_237  \
# 0  Urbano        None  1561972  26200906        0.0  VIVIENDA      TRUE
# 1  Urbano        None  1813259  27383608        0.0   VIVIENDA     TRUE
#
#   item_23 item_24 item_33 item_598 item_601  item_43  item_99 item_35  \
# 0      SI      NO     NaN      NaN       DA      NaN    122.8     NaN
# 1     NaN     NaN     NaN      NaN      NaN      NaN      NaN     NaN
#
#    item_111 item_599  item_108 item_603  item_190 item_192 item_588 item_248  \
# 0      0.06      NaN      9.18      NaN       NaN      NaN      NaN      NaN
# 1       NaN      NaN       NaN      NaN   16763.0      NaN      NaN      NaN
#
#   item_591 item_602  item_41  item_211 item_74  item_1889 item_597 item_600  \
# 0      NaN      NaN      NaN       NaN     NaN        NaN       GR      NaN
# 1      NaN      NaN      NaN       NaN     NaN        NaN       GR      NaN
#
#    item_37 item_1407 item_1410 item_68  item_1328 item_1334 item_594 item_67  \
# 0      NaN       NaN       NaN     NaN        NaN       NaN      NaN     NaN
# 1      NaN       NaN       NaN     NaN        NaN       NaN      NaN     NaN
#
#   item_1408  item_1352 item_1405  item_1283  item_1343  item_1346  item_1292  \
# 0       NaN        NaN       NaN        NaN        NaN        NaN        NaN
# 1       NaN        NaN       NaN        NaN        NaN        NaN        NaN
#
#    item_1298 item_69 item_1331  item_202  item_1349
# 0        NaN     NaN       NaN       NaN        NaN
# 1        NaN     NaN       NaN       NaN        NaN

# %%
ids = [
    1442,
    8,
    237,
    23,
    24,
    33,
    598,
    601,
    43,
    99,
    35,
    111,
    599,
    108,
    603,
    190,
    192,
    588,
    248,
    591,
    602,
    41,
    211,
    74,
    1889,
    597,
    600,
    37,
    1407,
    1410,
    68,
    1328,
    1334,
    594,
    67,
    1408,
    1352,
    1405,
    1283,
    1343,
    1346,
    1292,
    1298,
    69,
    1331,
    202,
    1349,
]
df_odt_pacifico_prod_uid_desc = df_odt_pacifico_prod_uid_desc[
    [
        "item_288",
        "PLAN_COMERCIAL",
        "NIVEL",
        "LATI_USU",
        "LONG_USU",
        "AREA",
        "Descripcion",
        "odt",
        "orden",
    ]
]
df_merge = df_odt_pacifico_prod_uid_desc

# %%
for id in ids:
    df_item = df_2023[df_2023.id == id].reset_index(drop=True)

    df_merge = pd.merge(
        df_merge,  # Only include needed columns
        df_item[["odt", "value"]].drop_duplicates(subset="odt"),
        left_on="odt",
        right_on="odt",
        how="left",
    )
    # Directly rename 'value' to f'item_{id}'
    df_merge = df_merge.rename(columns={"value": f"item_{id}"})

df_odt_pacifico_prod_uid_desc_item = df_merge.copy()
# Another way to replace NaN with None
mask = pd.isna(df_odt_pacifico_prod_uid_desc_item["Descripcion"])
df_odt_pacifico_prod_uid_desc_item.loc[mask, "Descripcion"] = None

# %%
# Define the target data types based on dataset_decan_2023
dtype_mapping = {
    "item_288": "int64",
    "PLAN_COMERCIAL": "object",
    "NIVEL": "float64",
    "LATI_USU": "float64",
    "LONG_USU": "float64",
    "AREA": "object",
    "Descripcion": "object",
    "odt": "int64",
    "orden": "int64",
    "item_1442": "float64",
    "item_8": "object",
    "item_237": "object",
    "item_23": "object",
    "item_24": "object",
    "item_33": "object",
    "item_598": "object",
    "item_601": "object",
    "item_43": "float64",
    "item_99": "float64",
    "item_35": "object",
    "item_111": "float64",
    "item_599": "object",
    "item_108": "float64",
    "item_603": "object",
    "item_190": "float64",
    "item_192": "object",
    "item_588": "object",
    "item_248": "object",
    "item_591": "object",
    "item_602": "object",
    "item_41": "float64",
    "item_211": "float64",
    "item_74": "object",
    "item_1889": "float64",
    "item_597": "object",
    "item_600": "object",
    "item_37": "float64",
    "item_1407": "object",
    "item_1410": "object",
    "item_68": "object",
    "item_1328": "float64",
    "item_1334": "object",
    "item_594": "object",
    "item_67": "object",
    "item_1408": "object",
    "item_1352": "float64",
    "item_1405": "object",
    "item_1283": "float64",
    "item_1343": "float64",
    "item_1346": "float64",
    "item_1292": "float64",
    "item_1298": "float64",
    "item_69": "object",
    "item_1331": "object",
    "item_202": "float64",
    "item_1349": "float64",
}

# Convert each column that exists in df_odt_pacifico_prod_uid_desc_item
for col, dtype in dtype_mapping.items():
    if col in df_odt_pacifico_prod_uid_desc_item.columns:
        try:
            if dtype == "int64":
                # Handle NaN values before converting to integer
                df_odt_pacifico_prod_uid_desc_item[col] = (
                    df_odt_pacifico_prod_uid_desc_item[col].fillna(0).astype(dtype)
                )
            else:
                df_odt_pacifico_prod_uid_desc_item[col] = (
                    df_odt_pacifico_prod_uid_desc_item[col].astype(dtype)
                )
        except Exception as e:
            print(f"Error converting column {col} to {dtype}: {e}")
            # Try an alternative conversion method for problematic columns
            if dtype == "int64":
                df_odt_pacifico_prod_uid_desc_item[col] = (
                    pd.to_numeric(
                        df_odt_pacifico_prod_uid_desc_item[col], errors="coerce"
                    )
                    .fillna(0)
                    .astype(dtype)
                )
            elif dtype == "float64":
                df_odt_pacifico_prod_uid_desc_item[col] = pd.to_numeric(
                    df_odt_pacifico_prod_uid_desc_item[col], errors="coerce"
                )
            elif dtype == "object":
                df_odt_pacifico_prod_uid_desc_item[col] = (
                    df_odt_pacifico_prod_uid_desc_item[col].astype(str)
                )
                # Convert 'nan' strings back to None for object columns
                df_odt_pacifico_prod_uid_desc_item.loc[
                    df_odt_pacifico_prod_uid_desc_item[col] == "nan", col
                ] = None

# Verify the datatypes after conversion
print(df_odt_pacifico_prod_uid_desc_item.dtypes)
# Out:
# item_288            int64
# PLAN_COMERCIAL     object
# NIVEL             float64
# LATI_USU          float64
# LONG_USU          float64
# AREA               object
# Descripcion        object
# odt                 int64
# orden               int64
# item_1442         float64
# item_8             object
# item_237           object
# item_23            object
# item_24            object
# item_33            object
# item_598           object
# item_601           object
# item_43           float64
# item_99           float64
# item_35            object
# item_111          float64
# item_599           object
# item_108          float64
# item_603           object
# item_190          float64
# item_192           object
# item_588           object
# item_248           object
# item_591           object
# item_602           object
# item_41           float64
# item_211          float64
# item_74            object
# item_1889         float64
# item_597           object
# item_600           object
# item_37           float64
# item_1407          object
# item_1410          object
# item_68            object
# item_1328         float64
# item_1334          object
# item_594           object
# item_67            object
# item_1408          object
# item_1352         float64
# item_1405          object
# item_1283         float64
# item_1343         float64
# item_1346         float64
# item_1292         float64
# item_1298         float64
# item_69            object
# item_1331          object
# item_202          float64
# item_1349         float64
# dtype: object

# %%
# Función para generar el informe detallado
def generar_informe(dataset, output_file):
    resumen = []

    for columna in dataset.columns:
        # Información básica
        total_registros = len(dataset)
        vacios = dataset[columna].isnull().sum()
        tipo = dataset[columna].dtype

        # Resumen por tipo de dato
        if pd.api.types.is_numeric_dtype(dataset[columna]):
            estadisticas = dataset[columna].describe(percentiles=[0.25, 0.5, 0.75])
            resumen.append(
                {
                    "Variable": columna,
                    "Tipo": "Numérica",
                    "Total Registros": total_registros,
                    "Vacios": vacios,
                    "Mínimo": estadisticas["min"],
                    "1er Cuartil (25%)": estadisticas["25%"],
                    "Mediana (50%)": estadisticas["50%"],
                    "3er Cuartil (75%)": estadisticas["75%"],
                    "Máximo": estadisticas["max"],
                    "Media": estadisticas["mean"],
                }
            )

        elif pd.api.types.is_object_dtype(dataset[columna]):
            moda = (
                dataset[columna].mode()[0]
                if not dataset[columna].mode().empty
                else "Sin Moda"
            )
            frecuencias = dataset[columna].value_counts().to_dict()

            resumen.append(
                {
                    "Variable": columna,
                    "Tipo": "Categoría",
                    "Total Registros": total_registros,
                    "Vacios": vacios,
                    "Moda": moda,
                    "Frecuencias": frecuencias,
                }
            )

    # Crear DataFrame con el resumen
    informe_df = pd.DataFrame(resumen)

    # Guardar el informe en un archivo CSV
    informe_df.to_csv(data_processed_dir(output_file), index=False)

    print(f"Informe generado y guardado en: {output_file}")
    return informe_df

# %%
ruta_archivo = data_processed_dir("dataset_decantado_2023.csv")
nuevo_dataset = pd.read_csv(ruta_archivo)
reporte_jess = generar_informe(nuevo_dataset, "informe_dataset_2023j.csv")
# Out:
# Informe generado y guardado en: informe_dataset_2023j.csv
# /var/folders/pq/cm_j30pd6d5gvwryc4gttm2h0000gn/T/ipykernel_3963/2843258657.py:2: DtypeWarning: Columns (14,43,46,52) have mixed types. Specify dtype option on import or set low_memory=False.
#   nuevo_dataset = pd.read_csv(ruta_archivo)

# %%
reporte_frank = generar_informe(
    df_odt_pacifico_prod_uid_desc_item, "informe_dataset_2023f.csv"
)
# Out:
# Informe generado y guardado en: informe_dataset_2023f.csv

# %%
reporte_jess == reporte_frank
# Out:
# True
